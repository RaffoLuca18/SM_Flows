# %%
import jax
import jax.numpy as jnp
import optax


import matplotlib.pyplot as plt
import numpy as np


from tqdm import tqdm as tqdm
import pandas as pd


import time

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):


    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))


    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    
    return samples

# %%
def potential_grad(sample, mu, cov):


    precision = jnp.linalg.inv(cov)


    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=100, seed=0):

    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples


    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
        

    return evolved_samples

# %%
def compute_energy_distance(samples, evolved_samples):
    n = samples.shape[0]
    m = evolved_samples.shape[0]


    def pairwise_l2_norm(a, b):
        a_norm = jnp.sum(a**2, axis=1).reshape(-1, 1)
        b_norm = jnp.sum(b**2, axis=1).reshape(1, -1)
        sq_dists = a_norm + b_norm - 2 * a @ b.T
        return jnp.sqrt(jnp.maximum(sq_dists, 1e-10))


    d_xy = pairwise_l2_norm(samples, evolved_samples)
    d_xx = pairwise_l2_norm(samples, samples)
    d_yy = pairwise_l2_norm(evolved_samples, evolved_samples)


    ed = (
        2 * jnp.sum(d_xy) / (n * m)
        - jnp.sum(d_xx) / (n * n)
        - jnp.sum(d_yy) / (m * m)
    )


    return ed

# %%
def lm_loss(samples, mu, cov):


    evolved_samples = evolve_langevin(samples, mu, cov)


    return compute_energy_distance(samples, evolved_samples)

# %%
def lm_optimize(samples, n_epochs=1000, lr=1e-2, seed=10, eps=1e-2, plot_every=2):


    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    optimizer = optax.adam(lr)
    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov

# %%
def lm_optimize_with_tracking(
    samples,
    true_mu,
    true_cov,
    n_epochs=1000,
    base_lr=1e-2,
    seed=10,
    eps=1e-2,
    plot_every=1,
    use_lr_schedule=True
):
    

    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    if use_lr_schedule:
        lr_schedule = optax.linear_schedule(
            init_value=1e-2,
            end_value=base_lr,
            transition_steps=500
        )
        optimizer = optax.adam(learning_rate=lr_schedule)
    else:
        optimizer = optax.adam(learning_rate=base_lr)


    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    history = {
        "loss": [],
        "mu_l2": [],
        "cov_fro": [],
    }


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state, params)
        params = optax.apply_updates(params, updates)


        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val


        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov, history

# %%
mu = jnp.array([0.0, 1.0, -1.0])


cov = jnp.array([
    [1.0, 0.5, 0.2],
    [0.5, 1.0, 0.3],
    [0.2, 0.3, 1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)


time_start = time.time()


final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=800, base_lr=0.1, seed = 0)


time_end = time.time()
time_elapsed = time_end - time_start
time_round = time_elapsed/800
print(time_round)
# Out:
# epoch 0 | loss = 0.797180
# epoch 1 | loss = 0.750394
# epoch 2 | loss = 0.705530
# epoch 3 | loss = 0.662761
# epoch 4 | loss = 0.622228
# epoch 5 | loss = 0.584031
# epoch 6 | loss = 0.548222
# epoch 7 | loss = 0.514831
# epoch 8 | loss = 0.483834
# epoch 9 | loss = 0.455184
# epoch 10 | loss = 0.428806
# epoch 11 | loss = 0.404598
# epoch 12 | loss = 0.382456
# epoch 13 | loss = 0.362240
# epoch 14 | loss = 0.343821
# epoch 15 | loss = 0.327062
# epoch 16 | loss = 0.311831
# epoch 17 | loss = 0.297993
# epoch 18 | loss = 0.285417
# epoch 19 | loss = 0.273987
# epoch 20 | loss = 0.263592
# epoch 21 | loss = 0.254127
# epoch 22 | loss = 0.245494
# epoch 23 | loss = 0.237607
# epoch 24 | loss = 0.230392
# epoch 25 | loss = 0.223770
# epoch 26 | loss = 0.217688
# epoch 27 | loss = 0.212084
# epoch 28 | loss = 0.206901
# epoch 29 | loss = 0.202099
# epoch 30 | loss = 0.197644
# epoch 31 | loss = 0.193485
# epoch 32 | loss = 0.189590
# epoch 33 | loss = 0.185947
# epoch 34 | loss = 0.182514
# epoch 35 | loss = 0.179276
# epoch 36 | loss = 0.176205
# epoch 37 | loss = 0.173285
# epoch 38 | loss = 0.170506
# epoch 39 | loss = 0.167848
# epoch 40 | loss = 0.165297
# epoch 41 | loss = 0.162839
# epoch 42 | loss = 0.160469
# epoch 43 | loss = 0.158179
# epoch 44 | loss = 0.155954
# epoch 45 | loss = 0.153790
# epoch 46 | loss = 0.151680
# epoch 47 | loss = 0.149618
# epoch 48 | loss = 0.147598
# epoch 49 | loss = 0.145619
# epoch 50 | loss = 0.143674
# epoch 51 | loss = 0.141761
# epoch 52 | loss = 0.139871
# epoch 53 | loss = 0.138019
# epoch 54 | loss = 0.136183
# epoch 55 | loss = 0.134371
# epoch 56 | loss = 0.132587
# epoch 57 | loss = 0.130827
# epoch 58 | loss = 0.129086
# epoch 59 | loss = 0.127373
# epoch 60 | loss = 0.125685
# epoch 61 | loss = 0.124033
# epoch 62 | loss = 0.122407
# epoch 63 | loss = 0.120815
# epoch 64 | loss = 0.119258
# epoch 65 | loss = 0.117741
# epoch 66 | loss = 0.116272
# epoch 67 | loss = 0.114847
# epoch 68 | loss = 0.113472
# epoch 69 | loss = 0.112154
# epoch 70 | loss = 0.110891
# epoch 71 | loss = 0.109691
# epoch 72 | loss = 0.108548
# epoch 73 | loss = 0.107472
# epoch 74 | loss = 0.106460
# epoch 75 | loss = 0.105512
# epoch 76 | loss = 0.104631
# epoch 77 | loss = 0.103806
# epoch 78 | loss = 0.103039
# epoch 79 | loss = 0.102328
# epoch 80 | loss = 0.101672
# epoch 81 | loss = 0.101064
# epoch 82 | loss = 0.100496
# epoch 83 | loss = 0.099968
# epoch 84 | loss = 0.099476
# epoch 85 | loss = 0.099013
# epoch 86 | loss = 0.098581
# epoch 87 | loss = 0.098170
# epoch 88 | loss = 0.097781
# epoch 89 | loss = 0.097412
# epoch 90 | loss = 0.097058
# epoch 91 | loss = 0.096713
# epoch 92 | loss = 0.096380
# epoch 93 | loss = 0.096055
# epoch 94 | loss = 0.095739
# epoch 95 | loss = 0.095427
# epoch 96 | loss = 0.095119
# epoch 97 | loss = 0.094814
# epoch 98 | loss = 0.094509
# epoch 99 | loss = 0.094208
# epoch 100 | loss = 0.093904
# epoch 101 | loss = 0.093608
# epoch 102 | loss = 0.093309
# epoch 103 | loss = 0.093012
# epoch 104 | loss = 0.092713
# epoch 105 | loss = 0.092411
# epoch 106 | loss = 0.092120
# epoch 107 | loss = 0.091825
# epoch 108 | loss = 0.091531
# epoch 109 | loss = 0.091238
# epoch 110 | loss = 0.090946
# epoch 111 | loss = 0.090662
# epoch 112 | loss = 0.090373
# epoch 113 | loss = 0.090089
# epoch 114 | loss = 0.089802
# epoch 115 | loss = 0.089522
# epoch 116 | loss = 0.089240
# epoch 117 | loss = 0.088964
# epoch 118 | loss = 0.088689
# epoch 119 | loss = 0.088411
# epoch 120 | loss = 0.088135
# epoch 121 | loss = 0.087865
# epoch 122 | loss = 0.087593
# epoch 123 | loss = 0.087320
# epoch 124 | loss = 0.087046
# epoch 125 | loss = 0.086783
# epoch 126 | loss = 0.086511
# epoch 127 | loss = 0.086240
# epoch 128 | loss = 0.085969
# epoch 129 | loss = 0.085698
# epoch 130 | loss = 0.085428
# epoch 131 | loss = 0.085155
# epoch 132 | loss = 0.084880
# epoch 133 | loss = 0.084605
# epoch 134 | loss = 0.084329
# epoch 135 | loss = 0.084053
# epoch 136 | loss = 0.083776
# epoch 137 | loss = 0.083494
# epoch 138 | loss = 0.083209
# epoch 139 | loss = 0.082925
# epoch 140 | loss = 0.082638
# epoch 141 | loss = 0.082349
# epoch 142 | loss = 0.082052
# epoch 143 | loss = 0.081759
# epoch 144 | loss = 0.081464
# epoch 145 | loss = 0.081164
# epoch 146 | loss = 0.080860
# epoch 147 | loss = 0.080551
# epoch 148 | loss = 0.080246
# epoch 149 | loss = 0.079935
# epoch 150 | loss = 0.079617
# epoch 151 | loss = 0.079304
# epoch 152 | loss = 0.078980
# epoch 153 | loss = 0.078654
# epoch 154 | loss = 0.078326
# epoch 155 | loss = 0.077993
# epoch 156 | loss = 0.077651
# epoch 157 | loss = 0.077313
# epoch 158 | loss = 0.076965
# epoch 159 | loss = 0.076619
# epoch 160 | loss = 0.076261
# epoch 161 | loss = 0.075905
# epoch 162 | loss = 0.075538
# epoch 163 | loss = 0.075173
# epoch 164 | loss = 0.074801
# epoch 165 | loss = 0.074420
# epoch 166 | loss = 0.074038
# epoch 167 | loss = 0.073652
# epoch 168 | loss = 0.073258
# epoch 169 | loss = 0.072857
# epoch 170 | loss = 0.072453
# epoch 171 | loss = 0.072045
# epoch 172 | loss = 0.071634
# epoch 173 | loss = 0.071209
# epoch 174 | loss = 0.070787
# epoch 175 | loss = 0.070355
# epoch 176 | loss = 0.069922
# epoch 177 | loss = 0.069483
# epoch 178 | loss = 0.069038
# epoch 179 | loss = 0.068588
# epoch 180 | loss = 0.068134
# epoch 181 | loss = 0.067674
# epoch 182 | loss = 0.067212
# epoch 183 | loss = 0.066742
# epoch 184 | loss = 0.066269
# epoch 185 | loss = 0.065797
# epoch 186 | loss = 0.065320
# epoch 187 | loss = 0.064840
# epoch 188 | loss = 0.064359
# epoch 189 | loss = 0.063875
# epoch 190 | loss = 0.063387
# epoch 191 | loss = 0.062903
# epoch 192 | loss = 0.062417
# epoch 193 | loss = 0.061932
# epoch 194 | loss = 0.061451
# epoch 195 | loss = 0.060967
# epoch 196 | loss = 0.060491
# epoch 197 | loss = 0.060017
# epoch 198 | loss = 0.059549
# epoch 199 | loss = 0.059090
# epoch 200 | loss = 0.058632
# epoch 201 | loss = 0.058183
# epoch 202 | loss = 0.057748
# epoch 203 | loss = 0.057319
# epoch 204 | loss = 0.056905
# epoch 205 | loss = 0.056504
# epoch 206 | loss = 0.056112
# epoch 207 | loss = 0.055743
# epoch 208 | loss = 0.055377
# epoch 209 | loss = 0.055041
# epoch 210 | loss = 0.054712
# epoch 211 | loss = 0.054406
# epoch 212 | loss = 0.054122
# epoch 213 | loss = 0.053850
# epoch 214 | loss = 0.053600
# epoch 215 | loss = 0.053369
# epoch 216 | loss = 0.053152
# epoch 217 | loss = 0.052954
# epoch 218 | loss = 0.052773
# epoch 219 | loss = 0.052608
# epoch 220 | loss = 0.052454
# epoch 221 | loss = 0.052312
# epoch 222 | loss = 0.052183
# epoch 223 | loss = 0.052056
# epoch 224 | loss = 0.051940
# epoch 225 | loss = 0.051827
# epoch 226 | loss = 0.051718
# epoch 227 | loss = 0.051608
# epoch 228 | loss = 0.051500
# epoch 229 | loss = 0.051388
# epoch 230 | loss = 0.051273
# epoch 231 | loss = 0.051163
# epoch 232 | loss = 0.051037
# epoch 233 | loss = 0.050912
# epoch 234 | loss = 0.050785
# epoch 235 | loss = 0.050651
# epoch 236 | loss = 0.050511
# epoch 237 | loss = 0.050365
# epoch 238 | loss = 0.050216
# epoch 239 | loss = 0.050062
# epoch 240 | loss = 0.049903
# epoch 241 | loss = 0.049742
# epoch 242 | loss = 0.049573
# epoch 243 | loss = 0.049402
# epoch 244 | loss = 0.049227
# epoch 245 | loss = 0.049045
# epoch 246 | loss = 0.048863
# epoch 247 | loss = 0.048676
# epoch 248 | loss = 0.048483
# epoch 249 | loss = 0.048288
# epoch 250 | loss = 0.048086
# epoch 251 | loss = 0.047883
# epoch 252 | loss = 0.047673
# epoch 253 | loss = 0.047461
# epoch 254 | loss = 0.047245
# epoch 255 | loss = 0.047021
# epoch 256 | loss = 0.046794
# epoch 257 | loss = 0.046561
# epoch 258 | loss = 0.046321
# epoch 259 | loss = 0.046076
# epoch 260 | loss = 0.045824
# epoch 261 | loss = 0.045568
# epoch 262 | loss = 0.045301
# epoch 263 | loss = 0.045028
# epoch 264 | loss = 0.044749
# epoch 265 | loss = 0.044461
# epoch 266 | loss = 0.044165
# epoch 267 | loss = 0.043862
# epoch 268 | loss = 0.043549
# epoch 269 | loss = 0.043228
# epoch 270 | loss = 0.042893
# epoch 271 | loss = 0.042551
# epoch 272 | loss = 0.042199
# epoch 273 | loss = 0.041837
# epoch 274 | loss = 0.041466
# epoch 275 | loss = 0.041081
# epoch 276 | loss = 0.040686
# epoch 277 | loss = 0.040279
# epoch 278 | loss = 0.039857
# epoch 279 | loss = 0.039427
# epoch 280 | loss = 0.038982
# epoch 281 | loss = 0.038523
# epoch 282 | loss = 0.038052
# epoch 283 | loss = 0.037568
# epoch 284 | loss = 0.037064
# epoch 285 | loss = 0.036547
# epoch 286 | loss = 0.036013
# epoch 287 | loss = 0.035465
# epoch 288 | loss = 0.034903
# epoch 289 | loss = 0.034321
# epoch 290 | loss = 0.033717
# epoch 291 | loss = 0.033098
# epoch 292 | loss = 0.032460
# epoch 293 | loss = 0.031806
# epoch 294 | loss = 0.031130
# epoch 295 | loss = 0.030437
# epoch 296 | loss = 0.029722
# epoch 297 | loss = 0.028988
# epoch 298 | loss = 0.028231
# epoch 299 | loss = 0.027453
# epoch 300 | loss = 0.026658
# epoch 301 | loss = 0.025840
# epoch 302 | loss = 0.025004
# epoch 303 | loss = 0.024141
# epoch 304 | loss = 0.023266
# epoch 305 | loss = 0.022369
# epoch 306 | loss = 0.021461
# epoch 307 | loss = 0.020531
# epoch 308 | loss = 0.019595
# epoch 309 | loss = 0.018642
# epoch 310 | loss = 0.017689
# epoch 311 | loss = 0.016732
# epoch 312 | loss = 0.015773
# epoch 313 | loss = 0.014821
# epoch 314 | loss = 0.013879
# epoch 315 | loss = 0.012955
# epoch 316 | loss = 0.012053
# epoch 317 | loss = 0.011180
# epoch 318 | loss = 0.010339
# epoch 319 | loss = 0.009532
# epoch 320 | loss = 0.008766
# epoch 321 | loss = 0.008040
# epoch 322 | loss = 0.007361
# epoch 323 | loss = 0.006723
# epoch 324 | loss = 0.006126
# epoch 325 | loss = 0.005565
# epoch 326 | loss = 0.005040
# epoch 327 | loss = 0.004546
# epoch 328 | loss = 0.004083
# epoch 329 | loss = 0.003648
# epoch 330 | loss = 0.003234
# epoch 331 | loss = 0.002848
# epoch 332 | loss = 0.002494
# epoch 333 | loss = 0.002165
# epoch 334 | loss = 0.001874
# epoch 335 | loss = 0.001624
# epoch 336 | loss = 0.001412
# epoch 337 | loss = 0.001246
# epoch 338 | loss = 0.001122
# epoch 339 | loss = 0.001045
# epoch 340 | loss = 0.000998
# epoch 341 | loss = 0.000980
# epoch 342 | loss = 0.000985
# epoch 343 | loss = 0.000997
# epoch 344 | loss = 0.001011
# epoch 345 | loss = 0.001023
# epoch 346 | loss = 0.001031
# epoch 347 | loss = 0.001029
# epoch 348 | loss = 0.001025
# epoch 349 | loss = 0.001020
# epoch 350 | loss = 0.001011
# epoch 351 | loss = 0.001005
# epoch 352 | loss = 0.001001
# epoch 353 | loss = 0.000993
# epoch 354 | loss = 0.000988
# epoch 355 | loss = 0.000978
# epoch 356 | loss = 0.000970
# epoch 357 | loss = 0.000957
# epoch 358 | loss = 0.000941
# epoch 359 | loss = 0.000926
# epoch 360 | loss = 0.000908
# epoch 361 | loss = 0.000895
# epoch 362 | loss = 0.000879
# epoch 363 | loss = 0.000867
# epoch 364 | loss = 0.000858
# epoch 365 | loss = 0.000850
# epoch 366 | loss = 0.000843
# epoch 367 | loss = 0.000836
# epoch 368 | loss = 0.000833
# epoch 369 | loss = 0.000827
# epoch 370 | loss = 0.000820
# epoch 371 | loss = 0.000815
# epoch 372 | loss = 0.000810
# epoch 373 | loss = 0.000808
# epoch 374 | loss = 0.000805
# epoch 375 | loss = 0.000803
# epoch 376 | loss = 0.000803
# epoch 377 | loss = 0.000801
# epoch 378 | loss = 0.000803
# epoch 379 | loss = 0.000805
# epoch 380 | loss = 0.000802
# epoch 381 | loss = 0.000803
# epoch 382 | loss = 0.000802
# epoch 383 | loss = 0.000798
# epoch 384 | loss = 0.000802
# epoch 385 | loss = 0.000802
# epoch 386 | loss = 0.000801
# epoch 387 | loss = 0.000802
# epoch 388 | loss = 0.000802
# epoch 389 | loss = 0.000801
# epoch 390 | loss = 0.000802
# epoch 391 | loss = 0.000798
# epoch 392 | loss = 0.000800
# epoch 393 | loss = 0.000801
# epoch 394 | loss = 0.000799
# epoch 395 | loss = 0.000800
# epoch 396 | loss = 0.000798
# epoch 397 | loss = 0.000796
# epoch 398 | loss = 0.000798
# epoch 399 | loss = 0.000797
# epoch 400 | loss = 0.000795
# epoch 401 | loss = 0.000798
# epoch 402 | loss = 0.000798
# epoch 403 | loss = 0.000798
# epoch 404 | loss = 0.000797
# epoch 405 | loss = 0.000797
# epoch 406 | loss = 0.000798
# epoch 407 | loss = 0.000800
# epoch 408 | loss = 0.000793
# epoch 409 | loss = 0.000795
# epoch 410 | loss = 0.000798
# epoch 411 | loss = 0.000799
# epoch 412 | loss = 0.000797
# epoch 413 | loss = 0.000793
# epoch 414 | loss = 0.000796
# epoch 415 | loss = 0.000795
# epoch 416 | loss = 0.000796
# epoch 417 | loss = 0.000798
# epoch 418 | loss = 0.000797
# epoch 419 | loss = 0.000796
# epoch 420 | loss = 0.000797
# epoch 421 | loss = 0.000796
# epoch 422 | loss = 0.000797
# epoch 423 | loss = 0.000796
# epoch 424 | loss = 0.000796
# epoch 425 | loss = 0.000796
# epoch 426 | loss = 0.000794
# epoch 427 | loss = 0.000798
# epoch 428 | loss = 0.000799
# epoch 429 | loss = 0.000795
# epoch 430 | loss = 0.000793
# epoch 431 | loss = 0.000796
# epoch 432 | loss = 0.000797
# epoch 433 | loss = 0.000795
# epoch 434 | loss = 0.000797
# epoch 435 | loss = 0.000797
# epoch 436 | loss = 0.000795
# epoch 437 | loss = 0.000795
# epoch 438 | loss = 0.000796
# epoch 439 | loss = 0.000795
# epoch 440 | loss = 0.000795
# epoch 441 | loss = 0.000796
# epoch 442 | loss = 0.000796
# epoch 443 | loss = 0.000797
# epoch 444 | loss = 0.000797
# epoch 445 | loss = 0.000798
# epoch 446 | loss = 0.000798
# epoch 447 | loss = 0.000796
# epoch 448 | loss = 0.000798
# epoch 449 | loss = 0.000797
# epoch 450 | loss = 0.000796
# epoch 451 | loss = 0.000799
# epoch 452 | loss = 0.000798
# epoch 453 | loss = 0.000797
# epoch 454 | loss = 0.000796
# epoch 455 | loss = 0.000796
# epoch 456 | loss = 0.000796
# epoch 457 | loss = 0.000797
# epoch 458 | loss = 0.000797
# epoch 459 | loss = 0.000796
# epoch 460 | loss = 0.000797
# epoch 461 | loss = 0.000798
# epoch 462 | loss = 0.000797
# epoch 463 | loss = 0.000795
# epoch 464 | loss = 0.000796
# epoch 465 | loss = 0.000796
# epoch 466 | loss = 0.000795
# epoch 467 | loss = 0.000795
# epoch 468 | loss = 0.000795
# epoch 469 | loss = 0.000795
# epoch 470 | loss = 0.000795
# epoch 471 | loss = 0.000796
# epoch 472 | loss = 0.000796
# epoch 473 | loss = 0.000796
# epoch 474 | loss = 0.000796
# epoch 475 | loss = 0.000797
# epoch 476 | loss = 0.000796
# epoch 477 | loss = 0.000796
# epoch 478 | loss = 0.000796
# epoch 479 | loss = 0.000795
# epoch 480 | loss = 0.000796
# epoch 481 | loss = 0.000796
# epoch 482 | loss = 0.000796
# epoch 483 | loss = 0.000796
# epoch 484 | loss = 0.000796
# epoch 485 | loss = 0.000796
# epoch 486 | loss = 0.000797
# epoch 487 | loss = 0.000797
# epoch 488 | loss = 0.000797
# epoch 489 | loss = 0.000797
# epoch 490 | loss = 0.000797
# epoch 491 | loss = 0.000797
# epoch 492 | loss = 0.000796
# epoch 493 | loss = 0.000796
# epoch 494 | loss = 0.000796
# epoch 495 | loss = 0.000796
# epoch 496 | loss = 0.000796
# epoch 497 | loss = 0.000796
# epoch 498 | loss = 0.000797
# epoch 499 | loss = 0.000796
# epoch 500 | loss = 0.000796
# epoch 501 | loss = 0.000796
# epoch 502 | loss = 0.000796
# epoch 503 | loss = 0.000797
# epoch 504 | loss = 0.000796
# epoch 505 | loss = 0.000796
# epoch 506 | loss = 0.000796
# epoch 507 | loss = 0.000796
# epoch 508 | loss = 0.000797
# epoch 509 | loss = 0.000796
# epoch 510 | loss = 0.000796
# epoch 511 | loss = 0.000796
# epoch 512 | loss = 0.000796
# epoch 513 | loss = 0.000797
# epoch 514 | loss = 0.000797
# epoch 515 | loss = 0.000797
# epoch 516 | loss = 0.000797
# epoch 517 | loss = 0.000797
# epoch 518 | loss = 0.000796
# epoch 519 | loss = 0.000796
# epoch 520 | loss = 0.000796
# epoch 521 | loss = 0.000796
# epoch 522 | loss = 0.000796
# epoch 523 | loss = 0.000796
# epoch 524 | loss = 0.000796
# epoch 525 | loss = 0.000796
# epoch 526 | loss = 0.000796
# epoch 527 | loss = 0.000796
# epoch 528 | loss = 0.000796
# epoch 529 | loss = 0.000797
# epoch 530 | loss = 0.000796
# epoch 531 | loss = 0.000796
# epoch 532 | loss = 0.000797
# epoch 533 | loss = 0.000796
# epoch 534 | loss = 0.000797
# epoch 535 | loss = 0.000797
# epoch 536 | loss = 0.000797
# epoch 537 | loss = 0.000797
# epoch 538 | loss = 0.000797
# epoch 539 | loss = 0.000797
# epoch 540 | loss = 0.000796
# epoch 541 | loss = 0.000797
# epoch 542 | loss = 0.000797
# epoch 543 | loss = 0.000796
# epoch 544 | loss = 0.000796
# epoch 545 | loss = 0.000796
# epoch 546 | loss = 0.000796
# epoch 547 | loss = 0.000796
# epoch 548 | loss = 0.000796
# epoch 549 | loss = 0.000796
# epoch 550 | loss = 0.000796
# epoch 551 | loss = 0.000796
# epoch 552 | loss = 0.000796
# epoch 553 | loss = 0.000797
# epoch 554 | loss = 0.000796
# epoch 555 | loss = 0.000797
# epoch 556 | loss = 0.000797
# epoch 557 | loss = 0.000797
# epoch 558 | loss = 0.000796
# epoch 559 | loss = 0.000796
# epoch 560 | loss = 0.000796
# epoch 561 | loss = 0.000796
# epoch 562 | loss = 0.000796
# epoch 563 | loss = 0.000796
# epoch 564 | loss = 0.000796
# epoch 565 | loss = 0.000796
# epoch 566 | loss = 0.000796
# epoch 567 | loss = 0.000796
# epoch 568 | loss = 0.000797
# epoch 569 | loss = 0.000796
# epoch 570 | loss = 0.000796
# epoch 571 | loss = 0.000796
# epoch 572 | loss = 0.000796
# epoch 573 | loss = 0.000797
# epoch 574 | loss = 0.000796
# epoch 575 | loss = 0.000796
# epoch 576 | loss = 0.000796
# epoch 577 | loss = 0.000796
# epoch 578 | loss = 0.000796
# epoch 579 | loss = 0.000796
# epoch 580 | loss = 0.000796
# epoch 581 | loss = 0.000797
# epoch 582 | loss = 0.000796
# epoch 583 | loss = 0.000796
# epoch 584 | loss = 0.000796
# epoch 585 | loss = 0.000796
# epoch 586 | loss = 0.000796
# epoch 587 | loss = 0.000796
# epoch 588 | loss = 0.000796
# epoch 589 | loss = 0.000796
# epoch 590 | loss = 0.000796
# epoch 591 | loss = 0.000796
# epoch 592 | loss = 0.000796
# epoch 593 | loss = 0.000796
# epoch 594 | loss = 0.000796
# epoch 595 | loss = 0.000796
# epoch 596 | loss = 0.000796
# epoch 597 | loss = 0.000796
# epoch 598 | loss = 0.000796
# epoch 599 | loss = 0.000796
# epoch 600 | loss = 0.000796
# epoch 601 | loss = 0.000796
# epoch 602 | loss = 0.000797
# epoch 603 | loss = 0.000796
# epoch 604 | loss = 0.000796
# epoch 605 | loss = 0.000796
# epoch 606 | loss = 0.000796
# epoch 607 | loss = 0.000796
# epoch 608 | loss = 0.000796
# epoch 609 | loss = 0.000796
# epoch 610 | loss = 0.000796
# epoch 611 | loss = 0.000796
# epoch 612 | loss = 0.000796
# epoch 613 | loss = 0.000796
# epoch 614 | loss = 0.000796
# epoch 615 | loss = 0.000796
# epoch 616 | loss = 0.000796
# epoch 617 | loss = 0.000796
# epoch 618 | loss = 0.000796
# epoch 619 | loss = 0.000796
# epoch 620 | loss = 0.000796
# epoch 621 | loss = 0.000796
# epoch 622 | loss = 0.000796
# epoch 623 | loss = 0.000796
# epoch 624 | loss = 0.000797
# epoch 625 | loss = 0.000796
# epoch 626 | loss = 0.000796
# epoch 627 | loss = 0.000796
# epoch 628 | loss = 0.000796
# epoch 629 | loss = 0.000796
# epoch 630 | loss = 0.000796
# epoch 631 | loss = 0.000796
# epoch 632 | loss = 0.000796
# epoch 633 | loss = 0.000796
# epoch 634 | loss = 0.000796
# epoch 635 | loss = 0.000796
# epoch 636 | loss = 0.000796
# epoch 637 | loss = 0.000796
# epoch 638 | loss = 0.000796
# epoch 639 | loss = 0.000796
# epoch 640 | loss = 0.000796
# epoch 641 | loss = 0.000796
# epoch 642 | loss = 0.000796
# epoch 643 | loss = 0.000796
# epoch 644 | loss = 0.000796
# epoch 645 | loss = 0.000797
# epoch 646 | loss = 0.000797
# epoch 647 | loss = 0.000796
# epoch 648 | loss = 0.000796
# epoch 649 | loss = 0.000796
# epoch 650 | loss = 0.000796
# epoch 651 | loss = 0.000796
# epoch 652 | loss = 0.000797
# epoch 653 | loss = 0.000797
# epoch 654 | loss = 0.000796
# epoch 655 | loss = 0.000796
# epoch 656 | loss = 0.000796
# epoch 657 | loss = 0.000796
# epoch 658 | loss = 0.000796
# epoch 659 | loss = 0.000796
# epoch 660 | loss = 0.000796
# epoch 661 | loss = 0.000796
# epoch 662 | loss = 0.000796
# epoch 663 | loss = 0.000796
# epoch 664 | loss = 0.000796
# epoch 665 | loss = 0.000796
# epoch 666 | loss = 0.000796
# epoch 667 | loss = 0.000796
# epoch 668 | loss = 0.000796
# epoch 669 | loss = 0.000796
# epoch 670 | loss = 0.000796
# epoch 671 | loss = 0.000796
# epoch 672 | loss = 0.000796
# epoch 673 | loss = 0.000796
# epoch 674 | loss = 0.000796
# epoch 675 | loss = 0.000796
# epoch 676 | loss = 0.000796
# epoch 677 | loss = 0.000796
# epoch 678 | loss = 0.000796
# epoch 679 | loss = 0.000796
# epoch 680 | loss = 0.000796
# epoch 681 | loss = 0.000796
# epoch 682 | loss = 0.000796
# epoch 683 | loss = 0.000796
# epoch 684 | loss = 0.000796
# epoch 685 | loss = 0.000796
# epoch 686 | loss = 0.000796
# epoch 687 | loss = 0.000796
# epoch 688 | loss = 0.000796
# epoch 689 | loss = 0.000796
# epoch 690 | loss = 0.000796
# epoch 691 | loss = 0.000796
# epoch 692 | loss = 0.000796
# epoch 693 | loss = 0.000796
# epoch 694 | loss = 0.000796
# epoch 695 | loss = 0.000796
# epoch 696 | loss = 0.000796
# epoch 697 | loss = 0.000796
# epoch 698 | loss = 0.000796
# epoch 699 | loss = 0.000796
# epoch 700 | loss = 0.000796
# epoch 701 | loss = 0.000796
# epoch 702 | loss = 0.000796
# epoch 703 | loss = 0.000796
# epoch 704 | loss = 0.000796
# epoch 705 | loss = 0.000796
# epoch 706 | loss = 0.000796
# epoch 707 | loss = 0.000796
# epoch 708 | loss = 0.000796
# epoch 709 | loss = 0.000796
# epoch 710 | loss = 0.000796
# epoch 711 | loss = 0.000796
# epoch 712 | loss = 0.000796
# epoch 713 | loss = 0.000796
# epoch 714 | loss = 0.000796
# epoch 715 | loss = 0.000796
# epoch 716 | loss = 0.000796
# epoch 717 | loss = 0.000796
# epoch 718 | loss = 0.000796
# epoch 719 | loss = 0.000796
# epoch 720 | loss = 0.000796
# epoch 721 | loss = 0.000796
# epoch 722 | loss = 0.000796
# epoch 723 | loss = 0.000796
# epoch 724 | loss = 0.000796
# epoch 725 | loss = 0.000796
# epoch 726 | loss = 0.000796
# epoch 727 | loss = 0.000796
# epoch 728 | loss = 0.000796
# epoch 729 | loss = 0.000796
# epoch 730 | loss = 0.000796
# epoch 731 | loss = 0.000796
# epoch 732 | loss = 0.000796
# epoch 733 | loss = 0.000796
# epoch 734 | loss = 0.000796
# epoch 735 | loss = 0.000796
# epoch 736 | loss = 0.000796
# epoch 737 | loss = 0.000796
# epoch 738 | loss = 0.000796
# epoch 739 | loss = 0.000796
# epoch 740 | loss = 0.000796
# epoch 741 | loss = 0.000796
# epoch 742 | loss = 0.000796
# epoch 743 | loss = 0.000796
# epoch 744 | loss = 0.000796
# epoch 745 | loss = 0.000796
# epoch 746 | loss = 0.000796
# epoch 747 | loss = 0.000796
# epoch 748 | loss = 0.000796
# epoch 749 | loss = 0.000796
# epoch 750 | loss = 0.000796
# epoch 751 | loss = 0.000796
# epoch 752 | loss = 0.000796
# epoch 753 | loss = 0.000796
# epoch 754 | loss = 0.000796
# epoch 755 | loss = 0.000796
# epoch 756 | loss = 0.000796
# epoch 757 | loss = 0.000796
# epoch 758 | loss = 0.000796
# epoch 759 | loss = 0.000796
# epoch 760 | loss = 0.000796
# epoch 761 | loss = 0.000796
# epoch 762 | loss = 0.000796
# epoch 763 | loss = 0.000796
# epoch 764 | loss = 0.000796
# epoch 765 | loss = 0.000796
# epoch 766 | loss = 0.000796
# epoch 767 | loss = 0.000796
# epoch 768 | loss = 0.000796
# epoch 769 | loss = 0.000796
# epoch 770 | loss = 0.000796
# epoch 771 | loss = 0.000796
# epoch 772 | loss = 0.000796
# epoch 773 | loss = 0.000796
# epoch 774 | loss = 0.000796
# epoch 775 | loss = 0.000796
# epoch 776 | loss = 0.000796
# epoch 777 | loss = 0.000796
# epoch 778 | loss = 0.000796
# epoch 779 | loss = 0.000796
# epoch 780 | loss = 0.000796
# epoch 781 | loss = 0.000796
# epoch 782 | loss = 0.000796
# epoch 783 | loss = 0.000796
# epoch 784 | loss = 0.000796
# epoch 785 | loss = 0.000796
# epoch 786 | loss = 0.000796
# epoch 787 | loss = 0.000796
# epoch 788 | loss = 0.000796
# epoch 789 | loss = 0.000796
# epoch 790 | loss = 0.000796
# epoch 791 | loss = 0.000796
# epoch 792 | loss = 0.000796
# epoch 793 | loss = 0.000796
# epoch 794 | loss = 0.000796
# epoch 795 | loss = 0.000796
# epoch 796 | loss = 0.000796
# epoch 797 | loss = 0.000796
# epoch 798 | loss = 0.000796
# epoch 799 | loss = 0.000796
# 0.19755612730979918

# %%
jnp.set_printoptions(precision=4, suppress=True)


print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu)/jnp.linalg.norm(mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov)/jnp.linalg.norm(cov), "\n\n\n")
# Out:
# [ 0.  1. -1.]
#
#  [ 0.0078  1.0816 -0.9697] 0.061789494
#
#
#
# [[1.  0.5 0.2]
#  [0.5 1.  0.3]
#  [0.2 0.3 1. ]]
#
#  [[1.0164 0.5172 0.1845]
#  [0.5172 1.0354 0.3168]
#  [0.1845 0.3168 1.0693]] 0.04600524

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="score matching loss")
plt.xlabel("step", fontsize=14)
plt.ylabel("loss", fontsize=14)
plt.title("loss evolution", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"]/np.linalg.norm(mu), label=r"$\| \mu - \hat{\mu} \|_2/\|\mu\|\_2$")
plt.plot(history_np["cov_fro"]/np.linalg.norm(cov), label=r"$\| \Sigma - \hat{\Sigma} \|_F/\|\Sigma\|_F$")
plt.yscale("log")
plt.xlabel("step", fontsize=14)
plt.title("reconstruction error", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.tight_layout()
plt.show()

# %%
sample_sizes = np.arange(50, 2001, 50)
n_steps = 800


all_losses = []
all_mu_errors = []
all_cov_errors = []


for n in tqdm(sample_sizes):
    samples = generate_gaussian_samples(mu, cov, n, seed=0)
    _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
    all_losses.append(np.array(history["loss"]))
    all_mu_errors.append(np.array(history["mu_l2"]))
    all_cov_errors.append(np.array(history["cov_fro"]))
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# epoch 0 | loss = 1.183229
# epoch 1 | loss = 1.131521
# epoch 2 | loss = 1.081406
# epoch 3 | loss = 1.033113
# epoch 4 | loss = 0.986838
# epoch 5 | loss = 0.942729
# epoch 6 | loss = 0.900918
# epoch 7 | loss = 0.861503
# epoch 8 | loss = 0.824520
# epoch 9 | loss = 0.789988
# epoch 10 | loss = 0.757884
# epoch 11 | loss = 0.728147
# epoch 12 | loss = 0.700698
# epoch 13 | loss = 0.675419
# epoch 14 | loss = 0.652190
# epoch 15 | loss = 0.630861
# epoch 16 | loss = 0.611292
# epoch 17 | loss = 0.593338
# epoch 18 | loss = 0.576860
# epoch 19 | loss = 0.561722
# epoch 20 | loss = 0.547799
# epoch 21 | loss = 0.534967
# epoch 22 | loss = 0.523117
# epoch 23 | loss = 0.512145
# epoch 24 | loss = 0.501964
# epoch 25 | loss = 0.492489
# epoch 26 | loss = 0.483649
# epoch 27 | loss = 0.475372
# epoch 28 | loss = 0.467609
# epoch 29 | loss = 0.460306
# epoch 30 | loss = 0.453423
# epoch 31 | loss = 0.446918
# epoch 32 | loss = 0.440766
# epoch 33 | loss = 0.434932
# epoch 34 | loss = 0.429396
# epoch 35 | loss = 0.424132
# epoch 36 | loss = 0.419126
# epoch 37 | loss = 0.414354
# epoch 38 | loss = 0.409815
# epoch 39 | loss = 0.405484
# epoch 40 | loss = 0.401352
# epoch 41 | loss = 0.397405
# epoch 42 | loss = 0.393637
# epoch 43 | loss = 0.390035
# epoch 44 | loss = 0.386592
# epoch 45 | loss = 0.383295
# epoch 46 | loss = 0.380146
# epoch 47 | loss = 0.377129
# epoch 48 | loss = 0.374236
# epoch 49 | loss = 0.371463
# epoch 50 | loss = 0.368797
# epoch 51 | loss = 0.366241
# epoch 52 | loss = 0.363780
# epoch 53 | loss = 0.361414
# epoch 54 | loss = 0.359132
# epoch 55 | loss = 0.356930
# epoch 56 | loss = 0.354805
# epoch 57 | loss = 0.352746
# epoch 58 | loss = 0.350754
# epoch 59 | loss = 0.348820
# epoch 60 | loss = 0.346944
# epoch 61 | loss = 0.345117
# epoch 62 | loss = 0.343341
# epoch 63 | loss = 0.341607
# epoch 64 | loss = 0.339913
# epoch 65 | loss = 0.338255
# epoch 66 | loss = 0.336630
# epoch 67 | loss = 0.335042
# epoch 68 | loss = 0.333474
# epoch 69 | loss = 0.331941
# epoch 70 | loss = 0.330427
# epoch 71 | loss = 0.328939
# epoch 72 | loss = 0.327470
# epoch 73 | loss = 0.326021
# epoch 74 | loss = 0.324588
# epoch 75 | loss = 0.323170
# epoch 76 | loss = 0.321767
# epoch 77 | loss = 0.320381
# epoch 78 | loss = 0.318999
# epoch 79 | loss = 0.317638
# epoch 80 | loss = 0.316281
# epoch 81 | loss = 0.314933
# epoch 82 | loss = 0.313591
# epoch 83 | loss = 0.312259
# epoch 84 | loss = 0.310933
# epoch 85 | loss = 0.309612
# epoch 86 | loss = 0.308293
# epoch 87 | loss = 0.306977
# epoch 88 | loss = 0.305662
# epoch 89 | loss = 0.304357
# epoch 90 | loss = 0.303042
# epoch 91 | loss = 0.301730
# epoch 92 | loss = 0.300416
# epoch 93 | loss = 0.299097
# epoch 94 | loss = 0.297775
# epoch 95 | loss = 0.296450
# epoch 96 | loss = 0.295113
# epoch 97 | loss = 0.293775
# epoch 98 | loss = 0.292424
# epoch 99 | loss = 0.291062
# epoch 100 | loss = 0.289692
# epoch 101 | loss = 0.288305
# epoch 102 | loss = 0.286908
# epoch 103 | loss = 0.285493
# epoch 104 | loss = 0.284062
# epoch 105 | loss = 0.282612
# epoch 106 | loss = 0.281138
# epoch 107 | loss = 0.279644
# epoch 108 | loss = 0.278126
# epoch 109 | loss = 0.276579
# epoch 110 | loss = 0.275008
# epoch 111 | loss = 0.273402
# epoch 112 | loss = 0.271770
# epoch 113 | loss = 0.270094
# epoch 114 | loss = 0.268389
# epoch 115 | loss = 0.266639
# epoch 116 | loss = 0.264849
# epoch 117 | loss = 0.263012
# epoch 118 | loss = 0.261126
# epoch 119 | loss = 0.259193
# epoch 120 | loss = 0.257208
# epoch 121 | loss = 0.255163
# epoch 122 | loss = 0.253063
# epoch 123 | loss = 0.250904
# epoch 124 | loss = 0.248678
# epoch 125 | loss = 0.246390
# epoch 126 | loss = 0.244032
# epoch 127 | loss = 0.241605
# epoch 128 | loss = 0.239106
# epoch 129 | loss = 0.236531
# epoch 130 | loss = 0.233881
# epoch 131 | loss = 0.231158
# epoch 132 | loss = 0.228351
# epoch 133 | loss = 0.225469
# epoch 134 | loss = 0.222505
# epoch 135 | loss = 0.219465
# epoch 136 | loss = 0.216344
# epoch 137 | loss = 0.213145
# epoch 138 | loss = 0.209872
# epoch 139 | loss = 0.206522
# epoch 140 | loss = 0.203107
# epoch 141 | loss = 0.199622
# epoch 142 | loss = 0.196074
# epoch 143 | loss = 0.192469
# epoch 144 | loss = 0.188817
# epoch 145 | loss = 0.185124
# epoch 146 | loss = 0.181415
# epoch 147 | loss = 0.177689
# epoch 148 | loss = 0.173971
# epoch 149 | loss = 0.170266
# epoch 150 | loss = 0.166579
# epoch 151 | loss = 0.162928
# epoch 152 | loss = 0.159306
# epoch 153 | loss = 0.155732
# epoch 154 | loss = 0.152213
# epoch 155 | loss = 0.148753
# epoch 156 | loss = 0.145363
# epoch 157 | loss = 0.142052
# epoch 158 | loss = 0.138806
# epoch 159 | loss = 0.135633
# epoch 160 | loss = 0.132518
# epoch 161 | loss = 0.129454
# epoch 162 | loss = 0.126432
# epoch 163 | loss = 0.123430
# epoch 164 | loss = 0.120444
# epoch 165 | loss = 0.117461
# epoch 166 | loss = 0.114462
# epoch 167 | loss = 0.111451
# epoch 168 | loss = 0.108407
# epoch 169 | loss = 0.105340
# epoch 170 | loss = 0.102247
# epoch 171 | loss = 0.099138
# epoch 172 | loss = 0.096025
# epoch 173 | loss = 0.092919
# epoch 174 | loss = 0.089846
# epoch 175 | loss = 0.086821
# epoch 176 | loss = 0.083877
# epoch 177 | loss = 0.081034
# epoch 178 | loss = 0.078324
# epoch 179 | loss = 0.075776
# epoch 180 | loss = 0.073424
# epoch 181 | loss = 0.071285
# epoch 182 | loss = 0.069370
# epoch 183 | loss = 0.067675
# epoch 184 | loss = 0.066197
# epoch 185 | loss = 0.064914
# epoch 186 | loss = 0.063807
# epoch 187 | loss = 0.062858
# epoch 188 | loss = 0.062035
# epoch 189 | loss = 0.061322
# epoch 190 | loss = 0.060696
# epoch 191 | loss = 0.060140
# epoch 192 | loss = 0.059635
# epoch 193 | loss = 0.059175
# epoch 194 | loss = 0.058745
# epoch 195 | loss = 0.058348
# epoch 196 | loss = 0.057972
# epoch 197 | loss = 0.057617
# epoch 198 | loss = 0.057271
# epoch 199 | loss = 0.056934
# epoch 200 | loss = 0.056596
# epoch 201 | loss = 0.056252
# epoch 202 | loss = 0.055903
# epoch 203 | loss = 0.055543
# epoch 204 | loss = 0.055187
# epoch 205 | loss = 0.054829
# epoch 206 | loss = 0.054478
# epoch 207 | loss = 0.054149
# epoch 208 | loss = 0.053840
# epoch 209 | loss = 0.053559
# epoch 210 | loss = 0.053305
# epoch 211 | loss = 0.053077
# epoch 212 | loss = 0.052877
# epoch 213 | loss = 0.052698
# epoch 214 | loss = 0.052534
# epoch 215 | loss = 0.052383
# epoch 216 | loss = 0.052238
# epoch 217 | loss = 0.052097
# epoch 218 | loss = 0.051960
# epoch 219 | loss = 0.051821
# epoch 220 | loss = 0.051688
# epoch 221 | loss = 0.051554
# epoch 222 | loss = 0.051421
# epoch 223 | loss = 0.051294
# epoch 224 | loss = 0.051171
# epoch 225 | loss = 0.051049
# epoch 226 | loss = 0.050932
# epoch 227 | loss = 0.050823
# epoch 228 | loss = 0.050716
# epoch 229 | loss = 0.050614
# epoch 230 | loss = 0.050518
# epoch 231 | loss = 0.050428
# epoch 232 | loss = 0.050335
# epoch 233 | loss = 0.050250
# epoch 234 | loss = 0.050165
# epoch 235 | loss = 0.050084
# epoch 236 | loss = 0.050004
# epoch 237 | loss = 0.049927
# epoch 238 | loss = 0.049852
# epoch 239 | loss = 0.049779
# epoch 240 | loss = 0.049706
# epoch 241 | loss = 0.049639
# epoch 242 | loss = 0.049568
# epoch 243 | loss = 0.049502
# epoch 244 | loss = 0.049433
# epoch 245 | loss = 0.049371
# epoch 246 | loss = 0.049306
# epoch 247 | loss = 0.049243
# epoch 248 | loss = 0.049180
# epoch 249 | loss = 0.049119
# epoch 250 | loss = 0.049061
# epoch 251 | loss = 0.049001
# epoch 252 | loss = 0.048943
# epoch 253 | loss = 0.048889
# epoch 254 | loss = 0.048831
# epoch 255 | loss = 0.048778
# epoch 256 | loss = 0.048723
# epoch 257 | loss = 0.048671
# epoch 258 | loss = 0.048615
# epoch 259 | loss = 0.048566
# epoch 260 | loss = 0.048515
# epoch 261 | loss = 0.048466
# epoch 262 | loss = 0.048414
# epoch 263 | loss = 0.048365
# epoch 264 | loss = 0.048314
# epoch 265 | loss = 0.048267
# epoch 266 | loss = 0.048216
# epoch 267 | loss = 0.048168
# epoch 268 | loss = 0.048122
# epoch 269 | loss = 0.048075
# epoch 270 | loss = 0.048029
# epoch 271 | loss = 0.047982
# epoch 272 | loss = 0.047937
# epoch 273 | loss = 0.047894
# epoch 274 | loss = 0.047848
# epoch 275 | loss = 0.047803
# epoch 276 | loss = 0.047761
# epoch 277 | loss = 0.047717
# epoch 278 | loss = 0.047672
# epoch 279 | loss = 0.047632
# epoch 280 | loss = 0.047585
# epoch 281 | loss = 0.047545
# epoch 282 | loss = 0.047499
# epoch 283 | loss = 0.047462
# epoch 284 | loss = 0.047419
# epoch 285 | loss = 0.047377
# epoch 286 | loss = 0.047339
#   0%|          | 0/40 [00:45<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 12
#      10 for n in tqdm(sample_sizes):
#      11     samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12     _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13     all_losses.append(np.array(history["loss"]))
#      14     all_mu_errors.append(np.array(history["mu_l2"]))
#
# Cell In[32], line 60, in lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs, base_lr, seed, eps, plot_every, use_lr_schedule)
#      52 history = {
#      53     "loss": [],
#      54     "mu_l2": [],
#      55     "cov_fro": [],
#      56 }
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#      62     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:479, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     477   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     478 if not has_aux:
# --> 479   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     480 else:
#     481   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:2143, in _vjp(fun, has_aux, *primals)
#    2141 if not has_aux:
#    2142   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2143   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2144   out_tree = out_tree()
#    2145 else:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:309, in vjp(traceable, primals, has_aux)
#     307 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     308   if not has_aux:
# --> 309     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     310   else:
#     311     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:283, in linearize(traceable, *primals, **kwargs)
#     281 has_aux = kwargs.pop('has_aux', False)
#     282 if config.use_direct_linearize.value:
# --> 283   return direct_linearize(traceable, primals, kwargs, has_aux=has_aux)
#     284 if not has_aux:
#     285   jvpfun = jvp(traceable)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:256, in direct_linearize(traceable, primals, kwargs, has_aux, tag)
#     251   aux_primals = [x.primal
#     252                  if isinstance(x, LinearizeTracer)
#     253                  and x._trace.tag is linearize_trace.tag
#     254                  else x for x in aux]
#     255 else:
# --> 256   ans = traceable.call_wrapped(*tracers)
#     257   aux = None
#     258 out_primals, out_tangents = unzip2(map(linearize_trace.to_primal_tangent_pair, ans))
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# Cell In[32], line 49, in lm_optimize_with_tracking.<locals>.loss_fn(params, samples)
#      47 A = params["A"]
#      48 cov = A.T @ A
# ---> 49 return lm_loss(samples, mu, cov)
#
# Cell In[30], line 4, in lm_loss(samples, mu, cov)
#       1 def lm_loss(samples, mu, cov):
# ----> 4     evolved_samples = evolve_langevin(samples, mu, cov)
#       7     return compute_energy_distance(samples, evolved_samples)
#
# Cell In[28], line 11, in evolve_langevin(samples, mu, cov, eps, n_evolution, seed)
#       9     key, subkey = jax.random.split(key)
#      10     grad = potential_grad(evolved_samples, mu, cov)
# ---> 11     noise = jax.random.normal(subkey, shape=evolved_samples.shape)
#      12     evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
#      15 return evolved_samples
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/random.py:761, in normal(key, shape, dtype, out_sharding)
#     758   raise ValueError(f"dtype argument to `normal` must be a float or complex dtype, "
#     759                    f"got {dtype}")
#     760 dtype = dtypes.canonicalize_dtype(dtype)
# --> 761 return maybe_auto_axes(_normal, out_sharding, shape=shape, dtype=dtype)(key)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/pjit.py:260, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255 if config.no_tracing.value:
#     256   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     257                      "`jit`, but 'no_tracing' is set")
#     259 outs, out_flat, out_tree, args_flat, jaxpr, executable, pgle_profiler = \
# --> 260     _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     262 maybe_fastpath_data = _get_fastpath_data(
#     263     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     264     jit_info.abstracted_axes, pgle_profiler)
#     266 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/pjit.py:149, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     147   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     148 else:
# --> 149   out_flat = jit_p.bind(*args_flat, **p.params)
#     150   compiled = None
#     151   profiler = None
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:576, in Primitive.bind(self, *args, **params)
#     574 def bind(self, *args, **params):
#     575   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 576   return self._true_bind(*args, **params)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:592, in Primitive._true_bind(self, *args, **params)
#     590 trace_ctx.set_trace(eval_trace)
#     591 try:
# --> 592   return self.bind_with_trace(prev_trace, args, params)
#     593 finally:
#     594   trace_ctx.set_trace(prev_trace)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:602, in Primitive.bind_with_trace(self, trace, args, params)
#     599   with set_current_trace(trace):
#     600     return self.to_lojax(*args, **params)  # type: ignore
# --> 602 return trace.process_primitive(self, args, params)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:732, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     728 tangent_nzs = [type(t) is not Zero for t in tangents_in]
#     729 if (all(type(t) is Zero for t in tangents_in) and
#     730     primitive is not core.mutable_array_p and
#     731     not any(isinstance(core.typeof(x), AbstractRef) for x in primals_in)):
# --> 732   return primitive.bind_with_trace(self.parent_trace, primals_in, params)
#     733 fallback = partial(fallback_linearize_rule, primitive)
#     734 lin = primitive_linearizations.get(primitive, fallback)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:602, in Primitive.bind_with_trace(self, trace, args, params)
#     599   with set_current_trace(trace):
#     600     return self.to_lojax(*args, **params)  # type: ignore
# --> 602 return trace.process_primitive(self, args, params)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:1126, in EvalTrace.process_primitive(self, primitive, args, params)
#    1124 args = map(full_lower, args)
#    1125 check_eval_args(args)
# -> 1126 return primitive.impl(*args, **params)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/pjit.py:1821, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1813 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1814 cache_key = pxla.JitGlobalCppCacheKeys(
#    1815     donate_argnums=donated_argnums, donate_argnames=None,
#    1816     device=None, backend=None,
#    (...)   1819     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1820     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1821 return xc._xla.pjit(
#    1822     name, f, call_impl_cache_miss, [], [], cache_key,
#    1823     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1824     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# KeyboardInterrupt:

# %%
loss_matrix = np.array(all_losses)
mu_err_matrix = np.array(all_mu_errors)/np.linalg.norm(mu)
cov_err_matrix = np.array(all_cov_errors)/np.linalg.norm(cov)


steps = np.linspace(0, n_steps, n_steps)
sample_sizes = np.arange(50, 2001, 50)


def plot_heatmap(data, title, ylabel, cmap="viridis", vmin=None, vmax=None):
    plt.imshow(data, aspect="auto", origin="lower", cmap=cmap,
               extent=[steps[0], steps[-1], sample_sizes[0], sample_sizes[-1]],
               vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.xlabel("step", fontsize=13)
    plt.ylabel("n_samples", fontsize=13)
    plt.title(title, fontsize=15)


plt.figure(figsize=(18, 5))


plt.subplot(1, 3, 1)
plot_heatmap(loss_matrix, "Loss heatmap", "n_samples")


plt.subplot(1, 3, 2)
plot_heatmap(mu_err_matrix, r"$\|\mu - \hat{\mu}\|_2/\|\mu\|_2$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.subplot(1, 3, 3)
plot_heatmap(cov_err_matrix, r"$\|\Sigma - \hat{\Sigma}\|_F/\|\Sigma\|_F$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.tight_layout()
plt.show()
