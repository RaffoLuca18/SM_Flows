# %%
import jax
import jax.numpy as jnp
import optax


import matplotlib.pyplot as plt
import numpy as np


from tqdm import tqdm as tqdm
import pandas as pd


import time

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):


    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))


    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    
    return samples

# %%
def potential_grad(sample, mu, cov):


    precision = jnp.linalg.inv(cov)


    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=100, seed=0):

    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples


    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
        

    return evolved_samples

# %%
def compute_energy_distance(samples, evolved_samples):
    n = samples.shape[0]
    m = evolved_samples.shape[0]


    def pairwise_l2_norm(a, b):
        a_norm = jnp.sum(a**2, axis=1).reshape(-1, 1)
        b_norm = jnp.sum(b**2, axis=1).reshape(1, -1)
        sq_dists = a_norm + b_norm - 2 * a @ b.T
        return jnp.sqrt(jnp.maximum(sq_dists, 1e-10))


    d_xy = pairwise_l2_norm(samples, evolved_samples)
    d_xx = pairwise_l2_norm(samples, samples)
    d_yy = pairwise_l2_norm(evolved_samples, evolved_samples)


    ed = (
        2 * jnp.sum(d_xy) / (n * m)
        - jnp.sum(d_xx) / (n * n)
        - jnp.sum(d_yy) / (m * m)
    )


    return ed

# %%
def lm_loss(samples, mu, cov):


    evolved_samples = evolve_langevin(samples, mu, cov)


    return compute_energy_distance(samples, evolved_samples)

# %%
def lm_optimize(samples, n_epochs=1000, lr=1e-2, seed=10, eps=1e-2, plot_every=2):


    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    optimizer = optax.adam(lr)
    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state)
        params = optax.apply_updates(params, updates)


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov

# %%
def lm_optimize_with_tracking(
    samples,
    true_mu,
    true_cov,
    n_epochs=1000,
    base_lr=1e-2,
    seed=10,
    eps=1e-2,
    plot_every=1,
    use_lr_schedule=True
):
    

    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    if use_lr_schedule:
        lr_schedule = optax.linear_schedule(
            init_value=1e-2,
            end_value=base_lr,
            transition_steps=500
        )
        optimizer = optax.adam(learning_rate=lr_schedule)
    else:
        optimizer = optax.adam(learning_rate=base_lr)


    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    history = {
        "loss": [],
        "mu_l2": [],
        "cov_fro": [],
    }


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state, params)
        params = optax.apply_updates(params, updates)


        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val


        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov, history

# %%
mu = jnp.array([0.0, 1.0, -1.0, 0.5, -0.5])


cov = jnp.array([
    [1.0, 0.4, 0.3, 0.2, 0.1],
    [0.4, 1.0, 0.5, 0.3, 0.2],
    [0.3, 0.5, 1.0, 0.4, 0.3],
    [0.2, 0.3, 0.4, 1.0, 0.5],
    [0.1, 0.2, 0.3, 0.5, 1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)


time_start = time.time()


final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=800, base_lr=0.1, seed = 0)


time_end = time.time()
time_elapsed = time_end - time_start
time_round = time_elapsed/800
print(time_round)
# Out:
# epoch 0 | loss = 0.259500
# epoch 1 | loss = 0.248261
# epoch 2 | loss = 0.238306
# epoch 3 | loss = 0.229522
# epoch 4 | loss = 0.221806
# epoch 5 | loss = 0.215034
# epoch 6 | loss = 0.209078
# epoch 7 | loss = 0.203813
# epoch 8 | loss = 0.199128
# epoch 9 | loss = 0.194933
# epoch 10 | loss = 0.191152
# epoch 11 | loss = 0.187715
# epoch 12 | loss = 0.184566
# epoch 13 | loss = 0.181676
# epoch 14 | loss = 0.178989
# epoch 15 | loss = 0.176491
# epoch 16 | loss = 0.174141
# epoch 17 | loss = 0.171920
# epoch 18 | loss = 0.169813
# epoch 19 | loss = 0.167798
# epoch 20 | loss = 0.165861
# epoch 21 | loss = 0.163980
# epoch 22 | loss = 0.162156
# epoch 23 | loss = 0.160376
# epoch 24 | loss = 0.158619
# epoch 25 | loss = 0.156885
# epoch 26 | loss = 0.155159
# epoch 27 | loss = 0.153436
# epoch 28 | loss = 0.151710
# epoch 29 | loss = 0.149973
# epoch 30 | loss = 0.148219
# epoch 31 | loss = 0.146450
# epoch 32 | loss = 0.144648
# epoch 33 | loss = 0.142821
# epoch 34 | loss = 0.140954
# epoch 35 | loss = 0.139062
# epoch 36 | loss = 0.137131
# epoch 37 | loss = 0.135174
# epoch 38 | loss = 0.133184
# epoch 39 | loss = 0.131186
# epoch 40 | loss = 0.129180
# epoch 41 | loss = 0.127182
# epoch 42 | loss = 0.125220
# epoch 43 | loss = 0.123326
# epoch 44 | loss = 0.121516
# epoch 45 | loss = 0.119823
# epoch 46 | loss = 0.118275
# epoch 47 | loss = 0.116899
# epoch 48 | loss = 0.115702
# epoch 49 | loss = 0.114687
# epoch 50 | loss = 0.113841
# epoch 51 | loss = 0.113145
# epoch 52 | loss = 0.112554
# epoch 53 | loss = 0.112033
# epoch 54 | loss = 0.111517
# epoch 55 | loss = 0.110958
# epoch 56 | loss = 0.110313
# epoch 57 | loss = 0.109543
# epoch 58 | loss = 0.108645
# epoch 59 | loss = 0.107623
# epoch 60 | loss = 0.106481
# epoch 61 | loss = 0.105245
# epoch 62 | loss = 0.103906
# epoch 63 | loss = 0.102491
# epoch 64 | loss = 0.101006
# epoch 65 | loss = 0.099459
# epoch 66 | loss = 0.097851
# epoch 67 | loss = 0.096180
# epoch 68 | loss = 0.094424
# epoch 69 | loss = 0.092563
# epoch 70 | loss = 0.090588
# epoch 71 | loss = 0.088482
# epoch 72 | loss = 0.086268
# epoch 73 | loss = 0.083963
# epoch 74 | loss = 0.081630
# epoch 75 | loss = 0.079340
# epoch 76 | loss = 0.077198
# epoch 77 | loss = 0.075313
# epoch 78 | loss = 0.073755
# epoch 79 | loss = 0.072535
# epoch 80 | loss = 0.071607
# epoch 81 | loss = 0.070905
# epoch 82 | loss = 0.070353
# epoch 83 | loss = 0.069865
# epoch 84 | loss = 0.069392
# epoch 85 | loss = 0.068936
# epoch 86 | loss = 0.068506
# epoch 87 | loss = 0.068100
# epoch 88 | loss = 0.067722
# epoch 89 | loss = 0.067397
# epoch 90 | loss = 0.067124
# epoch 91 | loss = 0.066893
# epoch 92 | loss = 0.066703
# epoch 93 | loss = 0.066535
# epoch 94 | loss = 0.066383
# epoch 95 | loss = 0.066222
# epoch 96 | loss = 0.066033
# epoch 97 | loss = 0.065808
# epoch 98 | loss = 0.065544
# epoch 99 | loss = 0.065257
# epoch 100 | loss = 0.064937
# epoch 101 | loss = 0.064603
# epoch 102 | loss = 0.064262
# epoch 103 | loss = 0.063925
# epoch 104 | loss = 0.063594
# epoch 105 | loss = 0.063261
# epoch 106 | loss = 0.062932
# epoch 107 | loss = 0.062606
# epoch 108 | loss = 0.062264
# epoch 109 | loss = 0.061921
# epoch 110 | loss = 0.061557
# epoch 111 | loss = 0.061189
# epoch 112 | loss = 0.060807
# epoch 113 | loss = 0.060420
# epoch 114 | loss = 0.060023
# epoch 115 | loss = 0.059615
# epoch 116 | loss = 0.059199
# epoch 117 | loss = 0.058777
# epoch 118 | loss = 0.058343
# epoch 119 | loss = 0.057894
# epoch 120 | loss = 0.057431
# epoch 121 | loss = 0.056952
# epoch 122 | loss = 0.056455
# epoch 123 | loss = 0.055939
# epoch 124 | loss = 0.055396
# epoch 125 | loss = 0.054833
# epoch 126 | loss = 0.054245
# epoch 127 | loss = 0.053630
# epoch 128 | loss = 0.052981
# epoch 129 | loss = 0.052301
# epoch 130 | loss = 0.051581
# epoch 131 | loss = 0.050816
# epoch 132 | loss = 0.050000
# epoch 133 | loss = 0.049124
# epoch 134 | loss = 0.048182
# epoch 135 | loss = 0.047175
# epoch 136 | loss = 0.046093
# epoch 137 | loss = 0.044930
# epoch 138 | loss = 0.043686
# epoch 139 | loss = 0.042373
# epoch 140 | loss = 0.040992
# epoch 141 | loss = 0.039574
# epoch 142 | loss = 0.038140
# epoch 143 | loss = 0.036740
# epoch 144 | loss = 0.035435
# epoch 145 | loss = 0.034288
# epoch 146 | loss = 0.033367
# epoch 147 | loss = 0.032693
# epoch 148 | loss = 0.032269
# epoch 149 | loss = 0.032046
# epoch 150 | loss = 0.031974
# epoch 151 | loss = 0.031993
# epoch 152 | loss = 0.032051
# epoch 153 | loss = 0.032114
# epoch 154 | loss = 0.032139
# epoch 155 | loss = 0.032124
# epoch 156 | loss = 0.032048
# epoch 157 | loss = 0.031913
# epoch 158 | loss = 0.031728
# epoch 159 | loss = 0.031481
# epoch 160 | loss = 0.031191
# epoch 161 | loss = 0.030866
# epoch 162 | loss = 0.030541
# epoch 163 | loss = 0.030243
# epoch 164 | loss = 0.029988
# epoch 165 | loss = 0.029761
# epoch 166 | loss = 0.029566
# epoch 167 | loss = 0.029385
# epoch 168 | loss = 0.029212
# epoch 169 | loss = 0.029048
# epoch 170 | loss = 0.028897
# epoch 171 | loss = 0.028748
# epoch 172 | loss = 0.028603
# epoch 173 | loss = 0.028451
# epoch 174 | loss = 0.028290
# epoch 175 | loss = 0.028104
# epoch 176 | loss = 0.027904
# epoch 177 | loss = 0.027678
# epoch 178 | loss = 0.027437
# epoch 179 | loss = 0.027184
# epoch 180 | loss = 0.026931
# epoch 181 | loss = 0.026657
# epoch 182 | loss = 0.026386
# epoch 183 | loss = 0.026104
# epoch 184 | loss = 0.025811
# epoch 185 | loss = 0.025511
# epoch 186 | loss = 0.025201
# epoch 187 | loss = 0.024876
# epoch 188 | loss = 0.024535
# epoch 189 | loss = 0.024181
# epoch 190 | loss = 0.023797
# epoch 191 | loss = 0.023384
# epoch 192 | loss = 0.022941
# epoch 193 | loss = 0.022467
# epoch 194 | loss = 0.021954
# epoch 195 | loss = 0.021404
# epoch 196 | loss = 0.020818
# epoch 197 | loss = 0.020188
# epoch 198 | loss = 0.019514
# epoch 199 | loss = 0.018796
# epoch 200 | loss = 0.018024
# epoch 201 | loss = 0.017206
# epoch 202 | loss = 0.016330
# epoch 203 | loss = 0.015407
# epoch 204 | loss = 0.014440
# epoch 205 | loss = 0.013434
# epoch 206 | loss = 0.012411
# epoch 207 | loss = 0.011375
# epoch 208 | loss = 0.010363
# epoch 209 | loss = 0.009402
# epoch 210 | loss = 0.008510
# epoch 211 | loss = 0.007714
# epoch 212 | loss = 0.007020
# epoch 213 | loss = 0.006431
# epoch 214 | loss = 0.005935
# epoch 215 | loss = 0.005511
# epoch 216 | loss = 0.005123
# epoch 217 | loss = 0.004754
# epoch 218 | loss = 0.004391
# epoch 219 | loss = 0.004012
# epoch 220 | loss = 0.003632
# epoch 221 | loss = 0.003248
# epoch 222 | loss = 0.002886
# epoch 223 | loss = 0.002557
# epoch 224 | loss = 0.002273
# epoch 225 | loss = 0.002043
# epoch 226 | loss = 0.001873
# epoch 227 | loss = 0.001758
# epoch 228 | loss = 0.001690
# epoch 229 | loss = 0.001666
# epoch 230 | loss = 0.001669
# epoch 231 | loss = 0.001696
# epoch 232 | loss = 0.001723
# epoch 233 | loss = 0.001745
# epoch 234 | loss = 0.001753
# epoch 235 | loss = 0.001738
# epoch 236 | loss = 0.001700
# epoch 237 | loss = 0.001639
# epoch 238 | loss = 0.001567
# epoch 239 | loss = 0.001491
# epoch 240 | loss = 0.001428
# epoch 241 | loss = 0.001367
# epoch 242 | loss = 0.001325
# epoch 243 | loss = 0.001294
# epoch 244 | loss = 0.001272
# epoch 245 | loss = 0.001258
# epoch 246 | loss = 0.001252
# epoch 247 | loss = 0.001251
# epoch 248 | loss = 0.001258
# epoch 249 | loss = 0.001268
# epoch 250 | loss = 0.001275
# epoch 251 | loss = 0.001278
# epoch 252 | loss = 0.001280
# epoch 253 | loss = 0.001280
# epoch 254 | loss = 0.001273
# epoch 255 | loss = 0.001263
# epoch 256 | loss = 0.001251
# epoch 257 | loss = 0.001238
# epoch 258 | loss = 0.001220
# epoch 259 | loss = 0.001206
# epoch 260 | loss = 0.001197
# epoch 261 | loss = 0.001190
# epoch 262 | loss = 0.001186
# epoch 263 | loss = 0.001185
# epoch 264 | loss = 0.001190
# epoch 265 | loss = 0.001192
# epoch 266 | loss = 0.001195
# epoch 267 | loss = 0.001198
# epoch 268 | loss = 0.001198
# epoch 269 | loss = 0.001197
# epoch 270 | loss = 0.001194
# epoch 271 | loss = 0.001192
# epoch 272 | loss = 0.001191
# epoch 273 | loss = 0.001185
# epoch 274 | loss = 0.001184
# epoch 275 | loss = 0.001184
# epoch 276 | loss = 0.001187
# epoch 277 | loss = 0.001179
# epoch 278 | loss = 0.001183
# epoch 279 | loss = 0.001181
# epoch 280 | loss = 0.001183
# epoch 281 | loss = 0.001180
# epoch 282 | loss = 0.001181
# epoch 283 | loss = 0.001181
# epoch 284 | loss = 0.001184
# epoch 285 | loss = 0.001182
# epoch 286 | loss = 0.001182
# epoch 287 | loss = 0.001180
# epoch 288 | loss = 0.001179
# epoch 289 | loss = 0.001180
# epoch 290 | loss = 0.001181
# epoch 291 | loss = 0.001179
# epoch 292 | loss = 0.001178
# epoch 293 | loss = 0.001180
# epoch 294 | loss = 0.001181
# epoch 295 | loss = 0.001176
# epoch 296 | loss = 0.001180
# epoch 297 | loss = 0.001179
# epoch 298 | loss = 0.001178
# epoch 299 | loss = 0.001182
# epoch 300 | loss = 0.001176
# epoch 301 | loss = 0.001176
# epoch 302 | loss = 0.001181
# epoch 303 | loss = 0.001177
# epoch 304 | loss = 0.001177
# epoch 305 | loss = 0.001179
# epoch 306 | loss = 0.001178
# epoch 307 | loss = 0.001180
# epoch 308 | loss = 0.001178
# epoch 309 | loss = 0.001179
# epoch 310 | loss = 0.001176
# epoch 311 | loss = 0.001178
# epoch 312 | loss = 0.001179
# epoch 313 | loss = 0.001179
# epoch 314 | loss = 0.001177
# epoch 315 | loss = 0.001178
# epoch 316 | loss = 0.001181
# epoch 317 | loss = 0.001179
# epoch 318 | loss = 0.001178
# epoch 319 | loss = 0.001178
# epoch 320 | loss = 0.001179
# epoch 321 | loss = 0.001176
# epoch 322 | loss = 0.001178
# epoch 323 | loss = 0.001177
# epoch 324 | loss = 0.001177
# epoch 325 | loss = 0.001177
# epoch 326 | loss = 0.001179
# epoch 327 | loss = 0.001178
# epoch 328 | loss = 0.001178
# epoch 329 | loss = 0.001176
# epoch 330 | loss = 0.001177
# epoch 331 | loss = 0.001178
# epoch 332 | loss = 0.001178
# epoch 333 | loss = 0.001179
# epoch 334 | loss = 0.001179
# epoch 335 | loss = 0.001178
# epoch 336 | loss = 0.001181
# epoch 337 | loss = 0.001176
# epoch 338 | loss = 0.001176
# epoch 339 | loss = 0.001177
# epoch 340 | loss = 0.001178
# epoch 341 | loss = 0.001176
# epoch 342 | loss = 0.001179
# epoch 343 | loss = 0.001179
# epoch 344 | loss = 0.001181
# epoch 345 | loss = 0.001178
# epoch 346 | loss = 0.001179
# epoch 347 | loss = 0.001177
# epoch 348 | loss = 0.001176
# epoch 349 | loss = 0.001176
# epoch 350 | loss = 0.001178
# epoch 351 | loss = 0.001178
# epoch 352 | loss = 0.001179
# epoch 353 | loss = 0.001178
# epoch 354 | loss = 0.001177
# epoch 355 | loss = 0.001177
# epoch 356 | loss = 0.001176
# epoch 357 | loss = 0.001177
# epoch 358 | loss = 0.001179
# epoch 359 | loss = 0.001177
# epoch 360 | loss = 0.001177
# epoch 361 | loss = 0.001177
# epoch 362 | loss = 0.001178
# epoch 363 | loss = 0.001176
# epoch 364 | loss = 0.001177
# epoch 365 | loss = 0.001179
# epoch 366 | loss = 0.001178
# epoch 367 | loss = 0.001179
# epoch 368 | loss = 0.001178
# epoch 369 | loss = 0.001178
# epoch 370 | loss = 0.001176
# epoch 371 | loss = 0.001177
# epoch 372 | loss = 0.001178
# epoch 373 | loss = 0.001180
# epoch 374 | loss = 0.001179
# epoch 375 | loss = 0.001181
# epoch 376 | loss = 0.001179
# epoch 377 | loss = 0.001180
# epoch 378 | loss = 0.001179
# epoch 379 | loss = 0.001179
# epoch 380 | loss = 0.001178
# epoch 381 | loss = 0.001179
# epoch 382 | loss = 0.001178
# epoch 383 | loss = 0.001178
# epoch 384 | loss = 0.001178
# epoch 385 | loss = 0.001178
# epoch 386 | loss = 0.001178
# epoch 387 | loss = 0.001176
# epoch 388 | loss = 0.001177
# epoch 389 | loss = 0.001177
# epoch 390 | loss = 0.001179
# epoch 391 | loss = 0.001178
# epoch 392 | loss = 0.001178
# epoch 393 | loss = 0.001178
# epoch 394 | loss = 0.001178
# epoch 395 | loss = 0.001178
# epoch 396 | loss = 0.001179
# epoch 397 | loss = 0.001178
# epoch 398 | loss = 0.001178
# epoch 399 | loss = 0.001179
# epoch 400 | loss = 0.001178
# epoch 401 | loss = 0.001178
# epoch 402 | loss = 0.001178
# epoch 403 | loss = 0.001178
# epoch 404 | loss = 0.001178
# epoch 405 | loss = 0.001178
# epoch 406 | loss = 0.001178
# epoch 407 | loss = 0.001179
# epoch 408 | loss = 0.001178
# epoch 409 | loss = 0.001177
# epoch 410 | loss = 0.001178
# epoch 411 | loss = 0.001178
# epoch 412 | loss = 0.001178
# epoch 413 | loss = 0.001178
# epoch 414 | loss = 0.001179
# epoch 415 | loss = 0.001178
# epoch 416 | loss = 0.001178
# epoch 417 | loss = 0.001178
# epoch 418 | loss = 0.001178
# epoch 419 | loss = 0.001178
# epoch 420 | loss = 0.001179
# epoch 421 | loss = 0.001178
# epoch 422 | loss = 0.001178
# epoch 423 | loss = 0.001178
# epoch 424 | loss = 0.001179
# epoch 425 | loss = 0.001179
# epoch 426 | loss = 0.001178
# epoch 427 | loss = 0.001179
# epoch 428 | loss = 0.001178
# epoch 429 | loss = 0.001178
# epoch 430 | loss = 0.001178
# epoch 431 | loss = 0.001178
# epoch 432 | loss = 0.001178
# epoch 433 | loss = 0.001179
# epoch 434 | loss = 0.001179
# epoch 435 | loss = 0.001178
# epoch 436 | loss = 0.001177
# epoch 437 | loss = 0.001179
# epoch 438 | loss = 0.001177
# epoch 439 | loss = 0.001177
# epoch 440 | loss = 0.001178
# epoch 441 | loss = 0.001178
# epoch 442 | loss = 0.001178
# epoch 443 | loss = 0.001177
# epoch 444 | loss = 0.001179
# epoch 445 | loss = 0.001179
# epoch 446 | loss = 0.001179
# epoch 447 | loss = 0.001178
# epoch 448 | loss = 0.001178
# epoch 449 | loss = 0.001178
# epoch 450 | loss = 0.001178
# epoch 451 | loss = 0.001178
# epoch 452 | loss = 0.001179
# epoch 453 | loss = 0.001178
# epoch 454 | loss = 0.001178
# epoch 455 | loss = 0.001178
# epoch 456 | loss = 0.001178
# epoch 457 | loss = 0.001178
# epoch 458 | loss = 0.001179
# epoch 459 | loss = 0.001178
# epoch 460 | loss = 0.001179
# epoch 461 | loss = 0.001178
# epoch 462 | loss = 0.001178
# epoch 463 | loss = 0.001179
# epoch 464 | loss = 0.001178
# epoch 465 | loss = 0.001179
# epoch 466 | loss = 0.001179
# epoch 467 | loss = 0.001179
# epoch 468 | loss = 0.001179
# epoch 469 | loss = 0.001179
# epoch 470 | loss = 0.001179
# epoch 471 | loss = 0.001179
# epoch 472 | loss = 0.001179
# epoch 473 | loss = 0.001178
# epoch 474 | loss = 0.001178
# epoch 475 | loss = 0.001178
# epoch 476 | loss = 0.001179
# epoch 477 | loss = 0.001178
# epoch 478 | loss = 0.001178
# epoch 479 | loss = 0.001178
# epoch 480 | loss = 0.001178
# epoch 481 | loss = 0.001179
# epoch 482 | loss = 0.001179
# epoch 483 | loss = 0.001179
# epoch 484 | loss = 0.001179
# epoch 485 | loss = 0.001178
# epoch 486 | loss = 0.001179
# epoch 487 | loss = 0.001179
# epoch 488 | loss = 0.001179
# epoch 489 | loss = 0.001178
# epoch 490 | loss = 0.001179
# epoch 491 | loss = 0.001179
# epoch 492 | loss = 0.001178
# epoch 493 | loss = 0.001178
# epoch 494 | loss = 0.001178
# epoch 495 | loss = 0.001179
# epoch 496 | loss = 0.001179
# epoch 497 | loss = 0.001178
# epoch 498 | loss = 0.001178
# epoch 499 | loss = 0.001178
# epoch 500 | loss = 0.001179
# epoch 501 | loss = 0.001179
# epoch 502 | loss = 0.001179
# epoch 503 | loss = 0.001179
# epoch 504 | loss = 0.001179
# epoch 505 | loss = 0.001179
# epoch 506 | loss = 0.001178
# epoch 507 | loss = 0.001178
# epoch 508 | loss = 0.001178
# epoch 509 | loss = 0.001178
# epoch 510 | loss = 0.001178
# epoch 511 | loss = 0.001178
# epoch 512 | loss = 0.001179
# epoch 513 | loss = 0.001178
# epoch 514 | loss = 0.001179
# epoch 515 | loss = 0.001178
# epoch 516 | loss = 0.001179
# epoch 517 | loss = 0.001178
# epoch 518 | loss = 0.001178
# epoch 519 | loss = 0.001178
# epoch 520 | loss = 0.001179
# epoch 521 | loss = 0.001179
# epoch 522 | loss = 0.001179
# epoch 523 | loss = 0.001178
# epoch 524 | loss = 0.001179
# epoch 525 | loss = 0.001178
# epoch 526 | loss = 0.001178
# epoch 527 | loss = 0.001178
# epoch 528 | loss = 0.001179
# epoch 529 | loss = 0.001179
# epoch 530 | loss = 0.001179
# epoch 531 | loss = 0.001178
# epoch 532 | loss = 0.001179
# epoch 533 | loss = 0.001178
# epoch 534 | loss = 0.001178
# epoch 535 | loss = 0.001179
# epoch 536 | loss = 0.001179
# epoch 537 | loss = 0.001179
# epoch 538 | loss = 0.001178
# epoch 539 | loss = 0.001179
# epoch 540 | loss = 0.001178
# epoch 541 | loss = 0.001179
# epoch 542 | loss = 0.001179
# epoch 543 | loss = 0.001179
# epoch 544 | loss = 0.001179
# epoch 545 | loss = 0.001179
# epoch 546 | loss = 0.001179
# epoch 547 | loss = 0.001179
# epoch 548 | loss = 0.001179
# epoch 549 | loss = 0.001179
# epoch 550 | loss = 0.001179
# epoch 551 | loss = 0.001178
# epoch 552 | loss = 0.001178
# epoch 553 | loss = 0.001178
# epoch 554 | loss = 0.001179
# epoch 555 | loss = 0.001179
# epoch 556 | loss = 0.001179
# epoch 557 | loss = 0.001178
# epoch 558 | loss = 0.001179
# epoch 559 | loss = 0.001179
# epoch 560 | loss = 0.001178
# epoch 561 | loss = 0.001179
# epoch 562 | loss = 0.001179
# epoch 563 | loss = 0.001178
# epoch 564 | loss = 0.001178
# epoch 565 | loss = 0.001178
# epoch 566 | loss = 0.001179
# epoch 567 | loss = 0.001178
# epoch 568 | loss = 0.001178
# epoch 569 | loss = 0.001179
# epoch 570 | loss = 0.001179
# epoch 571 | loss = 0.001179
# epoch 572 | loss = 0.001179
# epoch 573 | loss = 0.001178
# epoch 574 | loss = 0.001178
# epoch 575 | loss = 0.001178
# epoch 576 | loss = 0.001179
# epoch 577 | loss = 0.001179
# epoch 578 | loss = 0.001179
# epoch 579 | loss = 0.001178
# epoch 580 | loss = 0.001179
# epoch 581 | loss = 0.001179
# epoch 582 | loss = 0.001178
# epoch 583 | loss = 0.001178
# epoch 584 | loss = 0.001178
# epoch 585 | loss = 0.001178
# epoch 586 | loss = 0.001179
# epoch 587 | loss = 0.001178
# epoch 588 | loss = 0.001178
# epoch 589 | loss = 0.001178
# epoch 590 | loss = 0.001178
# epoch 591 | loss = 0.001179
# epoch 592 | loss = 0.001179
# epoch 593 | loss = 0.001179
# epoch 594 | loss = 0.001178
# epoch 595 | loss = 0.001179
# epoch 596 | loss = 0.001179
# epoch 597 | loss = 0.001178
# epoch 598 | loss = 0.001178
# epoch 599 | loss = 0.001178
# epoch 600 | loss = 0.001179
# epoch 601 | loss = 0.001179
# epoch 602 | loss = 0.001178
# epoch 603 | loss = 0.001178
# epoch 604 | loss = 0.001178
# epoch 605 | loss = 0.001179
# epoch 606 | loss = 0.001179
# epoch 607 | loss = 0.001178
# epoch 608 | loss = 0.001178
# epoch 609 | loss = 0.001179
# epoch 610 | loss = 0.001179
# epoch 611 | loss = 0.001178
# epoch 612 | loss = 0.001178
# epoch 613 | loss = 0.001178
# epoch 614 | loss = 0.001179
# epoch 615 | loss = 0.001178
# epoch 616 | loss = 0.001179
# epoch 617 | loss = 0.001179
# epoch 618 | loss = 0.001178
# epoch 619 | loss = 0.001179
# epoch 620 | loss = 0.001179
# epoch 621 | loss = 0.001179
# epoch 622 | loss = 0.001179
# epoch 623 | loss = 0.001179
# epoch 624 | loss = 0.001178
# epoch 625 | loss = 0.001179
# epoch 626 | loss = 0.001179
# epoch 627 | loss = 0.001179
# epoch 628 | loss = 0.001179
# epoch 629 | loss = 0.001179
# epoch 630 | loss = 0.001178
# epoch 631 | loss = 0.001178
# epoch 632 | loss = 0.001178
# epoch 633 | loss = 0.001179
# epoch 634 | loss = 0.001178
# epoch 635 | loss = 0.001178
# epoch 636 | loss = 0.001179
# epoch 637 | loss = 0.001179
# epoch 638 | loss = 0.001178
# epoch 639 | loss = 0.001178
# epoch 640 | loss = 0.001178
# epoch 641 | loss = 0.001179
# epoch 642 | loss = 0.001179
# epoch 643 | loss = 0.001178
# epoch 644 | loss = 0.001178
# epoch 645 | loss = 0.001178
# epoch 646 | loss = 0.001178
# epoch 647 | loss = 0.001178
# epoch 648 | loss = 0.001179
# epoch 649 | loss = 0.001179
# epoch 650 | loss = 0.001178
# epoch 651 | loss = 0.001179
# epoch 652 | loss = 0.001178
# epoch 653 | loss = 0.001179
# epoch 654 | loss = 0.001179
# epoch 655 | loss = 0.001179
# epoch 656 | loss = 0.001179
# epoch 657 | loss = 0.001179
# epoch 658 | loss = 0.001179
# epoch 659 | loss = 0.001178
# epoch 660 | loss = 0.001179
# epoch 661 | loss = 0.001178
# epoch 662 | loss = 0.001178
# epoch 663 | loss = 0.001179
# epoch 664 | loss = 0.001177
# epoch 665 | loss = 0.001178
# epoch 666 | loss = 0.001177
# epoch 667 | loss = 0.001179
# epoch 668 | loss = 0.001177
# epoch 669 | loss = 0.001179
# epoch 670 | loss = 0.001177
# epoch 671 | loss = 0.001179
# epoch 672 | loss = 0.001177
# epoch 673 | loss = 0.001179
# epoch 674 | loss = 0.001179
# epoch 675 | loss = 0.001178
# epoch 676 | loss = 0.001178
# epoch 677 | loss = 0.001178
# epoch 678 | loss = 0.001179
# epoch 679 | loss = 0.001177
# epoch 680 | loss = 0.001180
# epoch 681 | loss = 0.001178
# epoch 682 | loss = 0.001184
# epoch 683 | loss = 0.001189
# epoch 684 | loss = 0.001197
# epoch 685 | loss = 0.001217
# epoch 686 | loss = 0.001230
# epoch 687 | loss = 0.001235
# epoch 688 | loss = 0.001216
# epoch 689 | loss = 0.001185
# epoch 690 | loss = 0.001179
# epoch 691 | loss = 0.001201
# epoch 692 | loss = 0.001210
# epoch 693 | loss = 0.001192
# epoch 694 | loss = 0.001182
# epoch 695 | loss = 0.001187
# epoch 696 | loss = 0.001200
# epoch 697 | loss = 0.001192
# epoch 698 | loss = 0.001176
# epoch 699 | loss = 0.001183
# epoch 700 | loss = 0.001190
# epoch 701 | loss = 0.001181
# epoch 702 | loss = 0.001177
# epoch 703 | loss = 0.001182
# epoch 704 | loss = 0.001186
# epoch 705 | loss = 0.001182
# epoch 706 | loss = 0.001178
# epoch 707 | loss = 0.001180
# epoch 708 | loss = 0.001182
# epoch 709 | loss = 0.001181
# epoch 710 | loss = 0.001177
# epoch 711 | loss = 0.001179
# epoch 712 | loss = 0.001180
# epoch 713 | loss = 0.001180
# epoch 714 | loss = 0.001176
# epoch 715 | loss = 0.001180
# epoch 716 | loss = 0.001180
# epoch 717 | loss = 0.001177
# epoch 718 | loss = 0.001178
# epoch 719 | loss = 0.001181
# epoch 720 | loss = 0.001179
# epoch 721 | loss = 0.001179
# epoch 722 | loss = 0.001177
# epoch 723 | loss = 0.001180
# epoch 724 | loss = 0.001177
# epoch 725 | loss = 0.001178
# epoch 726 | loss = 0.001178
# epoch 727 | loss = 0.001180
# epoch 728 | loss = 0.001178
# epoch 729 | loss = 0.001177
# epoch 730 | loss = 0.001177
# epoch 731 | loss = 0.001181
# epoch 732 | loss = 0.001179
# epoch 733 | loss = 0.001178
# epoch 734 | loss = 0.001177
# epoch 735 | loss = 0.001179
# epoch 736 | loss = 0.001177
# epoch 737 | loss = 0.001179
# epoch 738 | loss = 0.001178
# epoch 739 | loss = 0.001178
# epoch 740 | loss = 0.001179
# epoch 741 | loss = 0.001178
# epoch 742 | loss = 0.001178
# epoch 743 | loss = 0.001177
# epoch 744 | loss = 0.001177
# epoch 745 | loss = 0.001179
# epoch 746 | loss = 0.001177
# epoch 747 | loss = 0.001177
# epoch 748 | loss = 0.001176
# epoch 749 | loss = 0.001177
# epoch 750 | loss = 0.001179
# epoch 751 | loss = 0.001180
# epoch 752 | loss = 0.001179
# epoch 753 | loss = 0.001178
# epoch 754 | loss = 0.001176
# epoch 755 | loss = 0.001179
# epoch 756 | loss = 0.001178
# epoch 757 | loss = 0.001177
# epoch 758 | loss = 0.001179
# epoch 759 | loss = 0.001179
# epoch 760 | loss = 0.001179
# epoch 761 | loss = 0.001179
# epoch 762 | loss = 0.001178
# epoch 763 | loss = 0.001178
# epoch 764 | loss = 0.001179
# epoch 765 | loss = 0.001179
# epoch 766 | loss = 0.001178
# epoch 767 | loss = 0.001176
# epoch 768 | loss = 0.001177
# epoch 769 | loss = 0.001179
# epoch 770 | loss = 0.001178
# epoch 771 | loss = 0.001179
# epoch 772 | loss = 0.001179
# epoch 773 | loss = 0.001177
# epoch 774 | loss = 0.001179
# epoch 775 | loss = 0.001177
# epoch 776 | loss = 0.001179
# epoch 777 | loss = 0.001178
# epoch 778 | loss = 0.001176
# epoch 779 | loss = 0.001179
# epoch 780 | loss = 0.001178
# epoch 781 | loss = 0.001178
# epoch 782 | loss = 0.001179
# epoch 783 | loss = 0.001176
# epoch 784 | loss = 0.001178
# epoch 785 | loss = 0.001178
# epoch 786 | loss = 0.001178
# epoch 787 | loss = 0.001179
# epoch 788 | loss = 0.001176
# epoch 789 | loss = 0.001179
# epoch 790 | loss = 0.001178
# epoch 791 | loss = 0.001179
# epoch 792 | loss = 0.001179
# epoch 793 | loss = 0.001178
# epoch 794 | loss = 0.001179
# epoch 795 | loss = 0.001177
# epoch 796 | loss = 0.001177
# epoch 797 | loss = 0.001178
# epoch 798 | loss = 0.001178
# epoch 799 | loss = 0.001179
# 0.19468039095401765

# %%
jnp.set_printoptions(precision=4, suppress=True)


print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu)/jnp.linalg.norm(mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov)/jnp.linalg.norm(cov), "\n\n\n")
# Out:
# [ 0.   1.  -1.   0.5 -0.5]
#
#  [ 0.0648  1.0353 -0.9063  0.4876 -0.4749] 0.077478275
#
#
#
# [[1.  0.4 0.3 0.2 0.1]
#  [0.4 1.  0.5 0.3 0.2]
#  [0.3 0.5 1.  0.4 0.3]
#  [0.2 0.3 0.4 1.  0.5]
#  [0.1 0.2 0.3 0.5 1. ]]
#
#  [[0.9448 0.3368 0.2479 0.1329 0.0511]
#  [0.3368 0.9966 0.4789 0.2864 0.1798]
#  [0.2479 0.4789 1.0358 0.4105 0.4013]
#  [0.1329 0.2864 0.4105 1.0286 0.4818]
#  [0.0511 0.1798 0.4013 0.4818 1.0904]] 0.09325124

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="score matching loss")
plt.xlabel("step", fontsize=14)
plt.ylabel("loss", fontsize=14)
plt.title("loss evolution", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"]/np.linalg.norm(mu), label=r"$\| \mu - \hat{\mu} \|_2/\|\mu\|\_2$")
plt.plot(history_np["cov_fro"]/np.linalg.norm(cov), label=r"$\| \Sigma - \hat{\Sigma} \|_F/\|\Sigma\|_F$")
plt.yscale("log")
plt.xlabel("step", fontsize=14)
plt.title("reconstruction error", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.tight_layout()
plt.show()

# %%
sample_sizes = np.arange(50, 2001, 50)
n_steps = 800


all_losses = []
all_mu_errors = []
all_cov_errors = []


for n in tqdm(sample_sizes):
    samples = generate_gaussian_samples(mu, cov, n, seed=0)
    _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
    all_losses.append(np.array(history["loss"]))
    all_mu_errors.append(np.array(history["mu_l2"]))
    all_cov_errors.append(np.array(history["cov_fro"]))
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# epoch 0 | loss = 0.272011
# epoch 1 | loss = 0.261484
# epoch 2 | loss = 0.252379
# epoch 3 | loss = 0.244361
# epoch 4 | loss = 0.237240
# epoch 5 | loss = 0.230903
#   0%|          | 0/40 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/tornado/platform/asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py:679, in run_forever()
#     678 while True:
# --> 679     self._run_once()
#     680     if self._stopping:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py:2027, in _run_once()
#    2026     else:
# -> 2027         handle._run()
#    2028 handle = None
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/events.py:89, in _run()
#      88 try:
# ---> 89     self._context.run(self._callback, *self._args)
#      90 except (SystemExit, KeyboardInterrupt):
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/kernelbase.py:519, in dispatch_queue()
#     518 try:
# --> 519     await self.process_one()
#     520 except Exception:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/kernelbase.py:508, in process_one()
#     506         self.control_stream.flush()
# --> 508 await dispatch(*args)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/kernelbase.py:400, in dispatch_shell()
#     399     if inspect.isawaitable(result):
# --> 400         await result
#     401 except Exception:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/ipkernel.py:368, in execute_request()
#     367 self._associate_new_top_level_threads_with(parent_header)
# --> 368 await super().execute_request(stream, ident, parent)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/kernelbase.py:767, in execute_request()
#     766 if inspect.isawaitable(reply_content):
# --> 767     reply_content = await reply_content
#     769 # Flush output before sending the reply.
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/ipkernel.py:455, in do_execute()
#     454 if accepts_params["cell_id"]:
# --> 455     res = shell.run_cell(
#     456         code,
#     457         store_history=store_history,
#     458         silent=silent,
#     459         cell_id=cell_id,
#     460     )
#     461 else:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/ipykernel/zmqshell.py:577, in run_cell()
#     576 self._last_traceback = None
# --> 577 return super().run_cell(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3116, in run_cell()
#    3115 try:
# -> 3116     result = self._run_cell(
#    3117         raw_cell, store_history, silent, shell_futures, cell_id
#    3118     )
#    3119 finally:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3171, in _run_cell()
#    3170 try:
# -> 3171     result = runner(coro)
#    3172 except BaseException as e:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3394, in run_cell_async()
#    3391 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3394 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3395        interactivity=interactivity, compiler=compiler, result=result)
#    3397 self.last_execution_succeeded = not has_raised
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3639, in run_ast_nodes()
#    3638     asy = compare(code)
# -> 3639 if await self.run_code(code, result, async_=asy):
#    3640     return True
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3699, in run_code()
#    3698     else:
# -> 3699         exec(code_obj, self.user_global_ns, self.user_ns)
#    3700 finally:
#    3701     # Reset our crash handler in place
#
# Cell In[14], line 12
#      11 samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12 _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13 all_losses.append(np.array(history["loss"]))
#
# Cell In[8], line 60, in lm_optimize_with_tracking()
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#
# Cell In[8], line 49, in loss_fn()
#      48 cov = A.T @ A
# ---> 49 return lm_loss(samples, mu, cov)
#
# Cell In[6], line 4, in lm_loss()
#       1 def lm_loss(samples, mu, cov):
# ----> 4     evolved_samples = evolve_langevin(samples, mu, cov)
#       7     return compute_energy_distance(samples, evolved_samples)
#
# Cell In[4], line 10, in evolve_langevin()
#       9 key, subkey = jax.random.split(key)
# ---> 10 grad = potential_grad(evolved_samples, mu, cov)
#      11 noise = jax.random.normal(subkey, shape=evolved_samples.shape)
#
# Cell In[3], line 4, in potential_grad()
#       1 def potential_grad(sample, mu, cov):
# ----> 4     precision = jnp.linalg.inv(cov)
#       7     return (sample - mu) @ precision
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 12
#      10 for n in tqdm(sample_sizes):
#      11     samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12     _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13     all_losses.append(np.array(history["loss"]))
#      14     all_mu_errors.append(np.array(history["mu_l2"]))
#
# Cell In[8], line 60, in lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs, base_lr, seed, eps, plot_every, use_lr_schedule)
#      52 history = {
#      53     "loss": [],
#      54     "mu_l2": [],
#      55     "cov_fro": [],
#      56 }
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#      62     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:484, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     482 _check_scalar(ans)
#     483 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 484 g = vjp_py(lax_internal._one(ans))
#     485 g = g[0] if isinstance(argnums, int) else g
#     486 if not has_aux:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/tree_util.py:510, in _HashableCallableShim.__call__(self, *args, **kw)
#     509 def __call__(self, *args, **kw):
# --> 510   return self.fun(*args, **kw)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:2065, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    2058   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    2059       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    2060     raise ValueError(
#    2061         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    2062         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    2063         f"because the corresponding output of the function {name} had JAX type "
#    2064         f"{aval.str_short()}")
# -> 2065 ans = fun(*args)
#    2066 return tree_unflatten(out_tree, ans)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/tree_util.py:510, in _HashableCallableShim.__call__(self, *args, **kw)
#     509 def __call__(self, *args, **kw):
# --> 510   return self.fun(*args, **kw)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:316, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     314 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     315 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 316 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     317 return map(instantiate_zeros, arg_cts)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:460, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     458       cts_out = [Zero(v.aval) for v in eqn.invars] if cts_out is Zero else cts_out
#     459       # FIXME: Some invars correspond to primals!
# --> 460       foreach(partial(write_cotangent, eqn.primitive), eqn.invars, cts_out)
#     462 cotangents_out = map(read_cotangent, jaxpr.invars)
#     463 return cotangents_out
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:350, in backward_pass.<locals>.write_cotangent(prim, v, ct)
#     346 if type(ct) is Zero:
#     347   # FIXME: This triggers a lot of failures!
#     348   # assert v.aval == ct.aval, (prim, v.aval, ct.aval)
#     349   return
# --> 350 ct_env[v] = add_tangents(ct_env[v], ct) if v in ct_env else ct
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:1070, in add_tangents(x, y)
#    1068   return x
#    1069 else:
# -> 1070   return add_jaxvals(x, y)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/ad_util.py:38, in add_jaxvals(x, y)
#      36   return ty.vspace_add(x, y)
#      37 x, y = core.standard_insert_pvary(x, y)
# ---> 38 return add_jaxvals_p.bind(x, y)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:576, in Primitive.bind(self, *args, **params)
#     574 def bind(self, *args, **params):
#     575   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 576   return self._true_bind(*args, **params)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:594, in Primitive._true_bind(self, *args, **params)
#     592   return self.bind_with_trace(prev_trace, args, params)
#     593 finally:
# --> 594   trace_ctx.set_trace(prev_trace)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:1226, in TracingContext.set_trace(self, trace)
#    1222 def is_top_level(self) -> bool:
#    1223   return (self.trace is eval_trace and
#    1224           self.axis_env is top_axis_env)
# -> 1226 def set_trace(self, trace):
#    1227   self.trace = trace
#    1228   ts = trace._weakref if trace is not None else None
#
# KeyboardInterrupt:

# %%
loss_matrix = np.array(all_losses)
mu_err_matrix = np.array(all_mu_errors)/np.linalg.norm(mu)
cov_err_matrix = np.array(all_cov_errors)/np.linalg.norm(cov)


steps = np.linspace(0, n_steps, n_steps)
sample_sizes = np.arange(50, 2001, 50)


def plot_heatmap(data, title, ylabel, cmap="viridis", vmin=None, vmax=None):
    plt.imshow(data, aspect="auto", origin="lower", cmap=cmap,
               extent=[steps[0], steps[-1], sample_sizes[0], sample_sizes[-1]],
               vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.xlabel("step", fontsize=13)
    plt.ylabel("n_samples", fontsize=13)
    plt.title(title, fontsize=15)


plt.figure(figsize=(18, 5))


plt.subplot(1, 3, 1)
plot_heatmap(loss_matrix, "Loss heatmap", "n_samples")


plt.subplot(1, 3, 2)
plot_heatmap(mu_err_matrix, r"$\|\mu - \hat{\mu}\|_2/\|\mu\|_2$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.subplot(1, 3, 3)
plot_heatmap(cov_err_matrix, r"$\|\Sigma - \hat{\Sigma}\|_F/\|\Sigma\|_F$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.tight_layout()
plt.show()
