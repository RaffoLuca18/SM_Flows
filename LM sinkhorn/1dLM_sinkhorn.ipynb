# %%
import jax
import jax.numpy as jnp
import optax


import matplotlib.pyplot as plt
import numpy as np


from tqdm import tqdm as tqdm
import pandas as pd


import time

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):


    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))


    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    
    return samples

# %%
def potential_grad(sample, mu, cov):


    precision = jnp.linalg.inv(cov)


    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=100, seed=0):

    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples


    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
        

    return evolved_samples

# %%
def pairwise_squared_distances(x, y):


    x_norm = jnp.sum(x**2, axis=1).reshape(-1, 1)
    y_norm = jnp.sum(y**2, axis=1).reshape(1, -1)


    return x_norm + y_norm - 2 * jnp.dot(x, y.T)


def sinkhorn(a, b, C, epsilon=0.1, n_iters=100):


    K = jnp.exp(-C / epsilon)
    u = jnp.ones_like(a)
    v = jnp.ones_like(b)


    for _ in range(n_iters):
        u = a / (K @ v + 1e-9)
        v = b / (K.T @ u + 1e-9)


    transport_plan = jnp.outer(u, v) * K
    return jnp.sum(transport_plan * C)


def compute_sinkhorn(samples, evolved_samples, epsilon=0.1, n_iters=10):


    n = samples.shape[0]
    m = evolved_samples.shape[0]

    
    a = jnp.ones(n) / n
    b = jnp.ones(m) / m


    C_xy = pairwise_squared_distances(samples, evolved_samples)
    C_xx = pairwise_squared_distances(samples, samples)
    C_yy = pairwise_squared_distances(evolved_samples, evolved_samples)


    sink_xy = sinkhorn(a, b, C_xy, epsilon, n_iters)
    sink_xx = sinkhorn(a, a, C_xx, epsilon, n_iters)
    sink_yy = sinkhorn(b, b, C_yy, epsilon, n_iters)


    return sink_xy - 0.5 * (sink_xx + sink_yy)

# %%
def lm_loss(samples, mu, cov):


    evolved_samples = evolve_langevin(samples, mu, cov)


    return compute_sinkhorn(samples, evolved_samples)

# %%
def lm_optimize_with_tracking(
    samples,
    true_mu,
    true_cov,
    n_epochs=1000,
    base_lr=1e-2,
    seed=10,
    eps=1e-2,
    plot_every=2,
    use_lr_schedule=True
):
    

    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    if use_lr_schedule:
        lr_schedule = optax.linear_schedule(
            init_value=1e-2,
            end_value=base_lr,
            transition_steps=500
        )
        optimizer = optax.adam(learning_rate=lr_schedule)
    else:
        optimizer = optax.adam(learning_rate=base_lr)


    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    history = {
        "loss": [],
        "mu_l2": [],
        "cov_fro": [],
    }


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state, params)
        params = optax.apply_updates(params, updates)


        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val


        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov, history

# %%
mu = jnp.array([1.0])


cov = jnp.array([
    [1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)


start_time = time.time()


final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=400, base_lr=0.1, seed = 0)


end_time = time.time()


elapsed_time = end_time - start_time
round_time = elapsed_time/400
print(round_time)
# Out:
# epoch 0 | loss = 0.058785
# epoch 2 | loss = 0.058517
# epoch 4 | loss = 0.058230
# epoch 6 | loss = 0.057924
# epoch 8 | loss = 0.057597
# epoch 10 | loss = 0.057246
# epoch 12 | loss = 0.056871
# epoch 14 | loss = 0.056469
# epoch 16 | loss = 0.056037
# epoch 18 | loss = 0.055575
# epoch 20 | loss = 0.055078
# epoch 22 | loss = 0.054545
# epoch 24 | loss = 0.053972
# epoch 26 | loss = 0.053355
# epoch 28 | loss = 0.052690
# epoch 30 | loss = 0.051973
# epoch 32 | loss = 0.051197
# epoch 34 | loss = 0.050357
# epoch 36 | loss = 0.049443
# epoch 38 | loss = 0.048441
# epoch 40 | loss = 0.047335
# epoch 42 | loss = 0.046095
# epoch 44 | loss = 0.044690
# epoch 46 | loss = 0.043088
# epoch 48 | loss = 0.041251
# epoch 50 | loss = 0.039132
# epoch 52 | loss = 0.036676
# epoch 54 | loss = 0.033811
# epoch 56 | loss = 0.030473
# epoch 58 | loss = 0.026566
# epoch 60 | loss = 0.021881
# epoch 62 | loss = 0.016538
# epoch 64 | loss = 0.010848
# epoch 66 | loss = 0.005692
# epoch 68 | loss = 0.002428
# epoch 70 | loss = 0.001882
# epoch 72 | loss = 0.003528
# epoch 74 | loss = 0.005257
# epoch 76 | loss = 0.005338
# epoch 78 | loss = 0.004079
# epoch 80 | loss = 0.002724
# epoch 82 | loss = 0.001981
# epoch 84 | loss = 0.001836
# epoch 86 | loss = 0.002001
# epoch 88 | loss = 0.002209
# epoch 90 | loss = 0.002307
# epoch 92 | loss = 0.002248
# epoch 94 | loss = 0.002071
# epoch 96 | loss = 0.001858
# epoch 98 | loss = 0.001692
# epoch 100 | loss = 0.001619
# epoch 102 | loss = 0.001631
# epoch 104 | loss = 0.001680
# epoch 106 | loss = 0.001710
# epoch 108 | loss = 0.001694
# epoch 110 | loss = 0.001642
# epoch 112 | loss = 0.001588
# epoch 114 | loss = 0.001563
# epoch 116 | loss = 0.001570
# epoch 118 | loss = 0.001589
# epoch 120 | loss = 0.001599
# epoch 122 | loss = 0.001590
# epoch 124 | loss = 0.001571
# epoch 126 | loss = 0.001556
# epoch 128 | loss = 0.001555
# epoch 130 | loss = 0.001561
# epoch 132 | loss = 0.001567
# epoch 134 | loss = 0.001565
# epoch 136 | loss = 0.001559
# epoch 138 | loss = 0.001554
# epoch 140 | loss = 0.001554
# epoch 142 | loss = 0.001556
# epoch 144 | loss = 0.001558
# epoch 146 | loss = 0.001557
# epoch 148 | loss = 0.001555
# epoch 150 | loss = 0.001554
# epoch 152 | loss = 0.001554
# epoch 154 | loss = 0.001555
# epoch 156 | loss = 0.001555
# epoch 158 | loss = 0.001554
# epoch 160 | loss = 0.001554
# epoch 162 | loss = 0.001554
# epoch 164 | loss = 0.001554
# epoch 166 | loss = 0.001554
# epoch 168 | loss = 0.001554
# epoch 170 | loss = 0.001554
# epoch 172 | loss = 0.001553
# epoch 174 | loss = 0.001553
# epoch 176 | loss = 0.001554
# epoch 178 | loss = 0.001554
# epoch 180 | loss = 0.001553
# epoch 182 | loss = 0.001553
# epoch 184 | loss = 0.001553
# epoch 186 | loss = 0.001553
# epoch 188 | loss = 0.001553
# epoch 190 | loss = 0.001553
# epoch 192 | loss = 0.001553
# epoch 194 | loss = 0.001553
# epoch 196 | loss = 0.001553
# epoch 198 | loss = 0.001553
# epoch 200 | loss = 0.001553
# epoch 202 | loss = 0.001553
# epoch 204 | loss = 0.001553
# epoch 206 | loss = 0.001553
# epoch 208 | loss = 0.001553
# epoch 210 | loss = 0.001553
# epoch 212 | loss = 0.001553
# epoch 214 | loss = 0.001553
# epoch 216 | loss = 0.001553
# epoch 218 | loss = 0.001553
# epoch 220 | loss = 0.001553
# epoch 222 | loss = 0.001553
# epoch 224 | loss = 0.001553
# epoch 226 | loss = 0.001553
# epoch 228 | loss = 0.001553
# epoch 230 | loss = 0.001553
# epoch 232 | loss = 0.001553
# epoch 234 | loss = 0.001553
# epoch 236 | loss = 0.001553
# epoch 238 | loss = 0.001553
# epoch 240 | loss = 0.001553
# epoch 242 | loss = 0.001553
# epoch 244 | loss = 0.001553
# epoch 246 | loss = 0.001553
# epoch 248 | loss = 0.001553
# epoch 250 | loss = 0.001553
# epoch 252 | loss = 0.001553
# epoch 254 | loss = 0.001553
# epoch 256 | loss = 0.001553
# epoch 258 | loss = 0.001553
# epoch 260 | loss = 0.001553
# epoch 262 | loss = 0.001553
# epoch 264 | loss = 0.001553
# epoch 266 | loss = 0.001553
# epoch 268 | loss = 0.001553
# epoch 270 | loss = 0.001553
# epoch 272 | loss = 0.001553
# epoch 274 | loss = 0.001553
# epoch 276 | loss = 0.001553
# epoch 278 | loss = 0.001553
# epoch 280 | loss = 0.001553
# epoch 282 | loss = 0.001553
# epoch 284 | loss = 0.001553
# epoch 286 | loss = 0.001553
# epoch 288 | loss = 0.001553
# epoch 290 | loss = 0.001553
# epoch 292 | loss = 0.001553
# epoch 294 | loss = 0.001553
# epoch 296 | loss = 0.001553
# epoch 298 | loss = 0.001553
# epoch 300 | loss = 0.001553
# epoch 302 | loss = 0.001553
# epoch 304 | loss = 0.001553
# epoch 306 | loss = 0.001553
# epoch 308 | loss = 0.001553
# epoch 310 | loss = 0.001553
# epoch 312 | loss = 0.001553
# epoch 314 | loss = 0.001553
# epoch 316 | loss = 0.001553
# epoch 318 | loss = 0.001553
# epoch 320 | loss = 0.001553
# epoch 322 | loss = 0.001553
# epoch 324 | loss = 0.001553
# epoch 326 | loss = 0.001553
# epoch 328 | loss = 0.001553
# epoch 330 | loss = 0.001553
# epoch 332 | loss = 0.001553
# epoch 334 | loss = 0.001553
# epoch 336 | loss = 0.001553
# epoch 338 | loss = 0.001553
# epoch 340 | loss = 0.001553
# epoch 342 | loss = 0.001553
# epoch 344 | loss = 0.001553
# epoch 346 | loss = 0.001553
# epoch 348 | loss = 0.001553
# epoch 350 | loss = 0.001553
# epoch 352 | loss = 0.001553
# epoch 354 | loss = 0.001553
# epoch 356 | loss = 0.001553
# epoch 358 | loss = 0.001553
# epoch 360 | loss = 0.001553
# epoch 362 | loss = 0.001553
# epoch 364 | loss = 0.001553
# epoch 366 | loss = 0.001553
# epoch 368 | loss = 0.001553
# epoch 370 | loss = 0.001553
# epoch 372 | loss = 0.001553
# epoch 374 | loss = 0.001553
# epoch 376 | loss = 0.001553
# epoch 378 | loss = 0.001553
# epoch 380 | loss = 0.001553
# epoch 382 | loss = 0.001553
# epoch 384 | loss = 0.001553
# epoch 386 | loss = 0.001553
# epoch 388 | loss = 0.001553
# epoch 390 | loss = 0.001553
# epoch 392 | loss = 0.001553
# epoch 394 | loss = 0.001553
# epoch 396 | loss = 0.001553
# epoch 398 | loss = 0.001553
# epoch 399 | loss = 0.001553
# 0.46890195727348327

# %%
jnp.set_printoptions(precision=4, suppress=True)


print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu)/jnp.linalg.norm(mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov)/jnp.linalg.norm(cov), "\n\n\n")
# Out:
# [1.]
#
#  [0.9346] 0.065399766
#
#
#
# [[1.]]
#
#  [[1.0127]] 0.012740374

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="score matching loss")
plt.xlabel("step", fontsize=14)
plt.ylabel("loss", fontsize=14)
plt.title("loss evolution", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"]/np.linalg.norm(mu), label=r"$\| \mu - \hat{\mu} \|_2/\|\mu\|\_2$")
plt.plot(history_np["cov_fro"]/np.linalg.norm(cov), label=r"$\| \Sigma - \hat{\Sigma} \|_F/\|\Sigma\|_F$")
plt.yscale("log")
plt.xlabel("step", fontsize=14)
plt.title("reconstruction error", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.tight_layout()
plt.show()

# %%
sample_sizes = np.arange(50, 2001, 50)
n_steps = 800


all_losses = []
all_mu_errors = []
all_cov_errors = []


for n in tqdm(sample_sizes):
    samples = generate_gaussian_samples(mu, cov, n, seed=0)
    _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
    all_losses.append(np.array(history["loss"]))
    all_mu_errors.append(np.array(history["mu_l2"]))
    all_cov_errors.append(np.array(history["cov_fro"]))
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# epoch 0 | loss = 0.076611
# epoch 2 | loss = 0.075852
#   0%|          | 0/40 [00:02<?, ?it/s]
# epoch 4 | loss = 0.075059
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[28], line 12
#      10 for n in tqdm(sample_sizes):
#      11     samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12     _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13     all_losses.append(np.array(history["loss"]))
#      14     all_mu_errors.append(np.array(history["mu_l2"]))
#
# Cell In[21], line 60, in lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs, base_lr, seed, eps, plot_every, use_lr_schedule)
#      52 history = {
#      53     "loss": [],
#      54     "mu_l2": [],
#      55     "cov_fro": [],
#      56 }
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#      62     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:479, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     477   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     478 if not has_aux:
# --> 479   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     480 else:
#     481   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:2143, in _vjp(fun, has_aux, *primals)
#    2141 if not has_aux:
#    2142   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2143   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2144   out_tree = out_tree()
#    2145 else:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:309, in vjp(traceable, primals, has_aux)
#     307 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     308   if not has_aux:
# --> 309     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     310   else:
#     311     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:283, in linearize(traceable, *primals, **kwargs)
#     281 has_aux = kwargs.pop('has_aux', False)
#     282 if config.use_direct_linearize.value:
# --> 283   return direct_linearize(traceable, primals, kwargs, has_aux=has_aux)
#     284 if not has_aux:
#     285   jvpfun = jvp(traceable)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:256, in direct_linearize(traceable, primals, kwargs, has_aux, tag)
#     251   aux_primals = [x.primal
#     252                  if isinstance(x, LinearizeTracer)
#     253                  and x._trace.tag is linearize_trace.tag
#     254                  else x for x in aux]
#     255 else:
# --> 256   ans = traceable.call_wrapped(*tracers)
#     257   aux = None
#     258 out_primals, out_tangents = unzip2(map(linearize_trace.to_primal_tangent_pair, ans))
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# Cell In[21], line 49, in lm_optimize_with_tracking.<locals>.loss_fn(params, samples)
#      47 A = params["A"]
#      48 cov = A.T @ A
# ---> 49 return lm_loss(samples, mu, cov)
#
# Cell In[20], line 7, in lm_loss(samples, mu, cov)
#       1 def lm_loss(samples, mu, cov):
#       4     evolved_samples = evolve_langevin(samples, mu, cov)
# ----> 7     return compute_sinkhorn(samples, evolved_samples)
#
# Cell In[19], line 45, in compute_sinkhorn(samples, evolved_samples, epsilon, n_iters)
#      41 C_yy = pairwise_squared_distances(evolved_samples, evolved_samples)
#      44 sink_xy = sinkhorn(a, b, C_xy, epsilon, n_iters)
# ---> 45 sink_xx = sinkhorn(a, a, C_xx, epsilon, n_iters)
#      46 sink_yy = sinkhorn(b, b, C_yy, epsilon, n_iters)
#      49 return sink_xy - 0.5 * (sink_xx + sink_yy)
#
# Cell In[19], line 14, in sinkhorn(a, b, C, epsilon, n_iters)
#      11 def sinkhorn(a, b, C, epsilon=0.1, n_iters=100):
# ---> 14     K = jnp.exp(-C / epsilon)
#      15     u = jnp.ones_like(a)
#      16     v = jnp.ones_like(b)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/traceback_util.py:176, in api_boundary.<locals>.reraise_with_filtered_traceback(*args, **kwargs)
#     153 def api_boundary(fun: C) -> C:
#     154   '''Wraps ``fun`` to form a boundary for filtering exception tracebacks.
#     155
#     156   When an exception occurs below ``fun``, this appends to it a custom
#    (...)    173   traceback that excludes the frames specific to JAX's implementation.
#     174   '''
# --> 176   @functools.wraps(fun)
#     177   def reraise_with_filtered_traceback(*args, **kwargs):
#     178     __tracebackhide__ = True
#     179     try:
#
# KeyboardInterrupt:

# %%
loss_matrix = np.array(all_losses)
mu_err_matrix = np.array(all_mu_errors)/np.linalg.norm(mu)
cov_err_matrix = np.array(all_cov_errors)/np.linalg.norm(cov)


steps = np.linspace(0, n_steps, n_steps)
sample_sizes = np.arange(50, 2001, 50)


def plot_heatmap(data, title, ylabel, cmap="viridis", vmin=None, vmax=None):
    plt.imshow(data, aspect="auto", origin="lower", cmap=cmap,
               extent=[steps[0], steps[-1], sample_sizes[0], sample_sizes[-1]],
               vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.xlabel("step", fontsize=13)
    plt.ylabel("n_samples", fontsize=13)
    plt.title(title, fontsize=15)


plt.figure(figsize=(18, 5))


plt.subplot(1, 3, 1)
plot_heatmap(loss_matrix, "Loss heatmap", "n_samples")


plt.subplot(1, 3, 2)
plot_heatmap(mu_err_matrix, r"$\|\mu - \hat{\mu}\|_2/\|\mu\|_2$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.subplot(1, 3, 3)
plot_heatmap(cov_err_matrix, r"$\|\Sigma - \hat{\Sigma}\|_F/\|\Sigma\|_F$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.tight_layout()
plt.show()
