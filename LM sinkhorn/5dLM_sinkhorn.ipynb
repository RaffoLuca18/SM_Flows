# %%
import jax
import jax.numpy as jnp
import optax


import matplotlib.pyplot as plt
import numpy as np


from tqdm import tqdm as tqdm
import pandas as pd


import time

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):


    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))


    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    
    return samples

# %%
def potential_grad(sample, mu, cov):


    eps = 1e-2
    precision = jnp.linalg.inv(cov + eps * jnp.eye(len(mu)))


    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=100, seed=0):

    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples


    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
        

    return evolved_samples

# %%
def pairwise_squared_distances(x, y):


    x_norm = jnp.sum(x**2, axis=1).reshape(-1, 1)
    y_norm = jnp.sum(y**2, axis=1).reshape(1, -1)


    return x_norm + y_norm - 2 * jnp.dot(x, y.T)


def sinkhorn(a, b, C, epsilon=0.1, n_iters=100):


    K = jnp.exp(-C / epsilon)
    u = jnp.ones_like(a)
    v = jnp.ones_like(b)


    for _ in range(n_iters):
        u = a / (K @ v + 1e-9)
        v = b / (K.T @ u + 1e-9)


    transport_plan = jnp.outer(u, v) * K
    return jnp.sum(transport_plan * C)


def compute_sinkhorn(samples, evolved_samples, epsilon=0.1, n_iters=12):


    n = samples.shape[0]
    m = evolved_samples.shape[0]

    
    a = jnp.ones(n) / n
    b = jnp.ones(m) / m


    C_xy = pairwise_squared_distances(samples, evolved_samples)
    C_xx = pairwise_squared_distances(samples, samples)
    C_yy = pairwise_squared_distances(evolved_samples, evolved_samples)


    sink_xy = sinkhorn(a, b, C_xy, epsilon, n_iters)
    sink_xx = sinkhorn(a, a, C_xx, epsilon, n_iters)
    sink_yy = sinkhorn(b, b, C_yy, epsilon, n_iters)


    return sink_xy - 0.5 * (sink_xx + sink_yy)

# %%
def lm_loss(samples, mu, cov):


    evolved_samples = evolve_langevin(samples, mu, cov)


    return compute_sinkhorn(samples, evolved_samples)

# %%
def lm_optimize_with_tracking(
    samples,
    true_mu,
    true_cov,
    n_epochs=1000,
    base_lr=1e-2,
    seed=10,
    eps=1e-2,
    plot_every=2,
    use_lr_schedule=True
):
    

    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    if use_lr_schedule:
        lr_schedule = optax.linear_schedule(
            init_value=1e-2,
            end_value=base_lr,
            transition_steps=500
        )
        optimizer = optax.adam(learning_rate=lr_schedule)
    else:
        optimizer = optax.adam(learning_rate=base_lr)


    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    history = {
        "loss": [],
        "mu_l2": [],
        "cov_fro": [],
    }


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state, params)
        params = optax.apply_updates(params, updates)


        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val


        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov, history

# %%
mu = jnp.array([0.0, 1.0, -1.0, 0.5, -0.5])


cov = jnp.array([
    [1.0, 0.4, 0.3, 0.2, 0.1],
    [0.4, 1.0, 0.5, 0.3, 0.2],
    [0.3, 0.5, 1.0, 0.4, 0.3],
    [0.2, 0.3, 0.4, 1.0, 0.5],
    [0.1, 0.2, 0.3, 0.5, 1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=80)


time_start = time.time()


final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=10, base_lr=0.1, seed = 0)


time_end = time.time()
time_elapsed = time_end - time_start
time_round = time_elapsed/10
print(time_round)
# Out:
# epoch 0 | loss = 0.628323
# epoch 2 | loss = 0.624436
# epoch 4 | loss = 0.622940
# epoch 6 | loss = 0.620910
# epoch 8 | loss = 0.619116
# epoch 9 | loss = 0.618402
# 0.7439847230911255

# %%
jnp.set_printoptions(precision=4, suppress=True)


print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu)/jnp.linalg.norm(mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov)/jnp.linalg.norm(cov), "\n\n\n")
# Out:
# [ 0.   1.  -1.   0.5 -0.5]
#
#  [ 1.0608 -0.9489 -0.7473 -1.1678 -0.9529] 1.7859274
#
#
#
# [[1.  0.4 0.3 0.2 0.1]
#  [0.4 1.  0.5 0.3 0.2]
#  [0.3 0.5 1.  0.4 0.3]
#  [0.2 0.3 0.4 1.  0.5]
#  [0.1 0.2 0.3 0.5 1. ]]
#
#  [[ 9.2816  5.9209 -2.2467  1.5885  0.3133]
#  [ 5.9209  7.5748 -2.3719  2.5564  1.1917]
#  [-2.2467 -2.3719  4.1771  1.8622 -0.3988]
#  [ 1.5885  2.5564  1.8622  4.054  -1.513 ]
#  [ 0.3133  1.1917 -0.3988 -1.513  10.9416]] 6.8954806

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="score matching loss")
plt.xlabel("step", fontsize=14)
plt.ylabel("loss", fontsize=14)
plt.title("loss evolution", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"]/np.linalg.norm(mu), label=r"$\| \mu - \hat{\mu} \|_2/\|\mu\|\_2$")
plt.plot(history_np["cov_fro"]/np.linalg.norm(cov), label=r"$\| \Sigma - \hat{\Sigma} \|_F/\|\Sigma\|_F$")
plt.yscale("log")
plt.xlabel("step", fontsize=14)
plt.title("reconstruction error", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.tight_layout()
plt.show()

# %%
print(ert)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 print(ert)
#
# NameError: name 'ert' is not defined

# %%
sample_sizes = np.arange(50, 2001, 50)
n_steps = 800


all_losses = []
all_mu_errors = []
all_cov_errors = []


for n in tqdm(sample_sizes):
    samples = generate_gaussian_samples(mu, cov, n, seed=0)
    _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
    all_losses.append(np.array(history["loss"]))
    all_mu_errors.append(np.array(history["mu_l2"]))
    all_cov_errors.append(np.array(history["cov_fro"]))
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# epoch 0 | loss = 0.941155
# epoch 2 | loss = 0.883739
# epoch 4 | loss = 0.869697
# epoch 6 | loss = 0.870454
# epoch 8 | loss = 0.859308
# epoch 10 | loss = 0.841573
# epoch 12 | loss = 0.819932
# epoch 14 | loss = 0.793619
# epoch 16 | loss = 0.770419
# epoch 18 | loss = 0.755229
# epoch 20 | loss = 0.743174
# epoch 22 | loss = 0.725972
# epoch 24 | loss = 0.695931
# epoch 26 | loss = 0.686305
# epoch 28 | loss = 0.686153
# epoch 30 | loss = 0.685190
# epoch 32 | loss = 0.682634
# epoch 34 | loss = 0.678495
# epoch 36 | loss = 0.673454
# epoch 38 | loss = 0.667336
# epoch 40 | loss = 0.654120
# epoch 42 | loss = 0.636751
# epoch 44 | loss = 0.628924
# epoch 46 | loss = 0.626428
# epoch 48 | loss = 0.626560
# epoch 50 | loss = 0.624868
# epoch 52 | loss = 0.621793
# epoch 54 | loss = 0.619235
# epoch 56 | loss = 0.616162
# epoch 58 | loss = 0.613153
# epoch 60 | loss = 0.611265
# epoch 62 | loss = 0.609962
# epoch 64 | loss = 0.608188
# epoch 66 | loss = 0.605761
# epoch 68 | loss = 0.603316
# epoch 70 | loss = 0.601135
# epoch 72 | loss = 0.598571
# epoch 74 | loss = 0.595614
# epoch 76 | loss = 0.593047
# epoch 78 | loss = 0.590473
# epoch 80 | loss = 0.587415
# epoch 82 | loss = 0.584002
#   0%|          | 0/40 [00:20<?, ?it/s]
# ---------------------------------------------------------------------------
# JaxStackTraceBeforeTransformation         Traceback (most recent call last)
# File <frozen runpy>:198, in _run_module_as_main()
#
# File <frozen runpy>:88, in _run_code()
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel_launcher.py:18
#      16 from ipykernel import kernelapp as app
# ---> 18 app.launch_new_instance()
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/traitlets/config/application.py:1075, in launch_instance()
#    1074 app.initialize(argv)
# -> 1075 app.start()
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/kernelapp.py:739, in start()
#     738 try:
# --> 739     self.io_loop.start()
#     740 except KeyboardInterrupt:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/tornado/platform/asyncio.py:211, in start()
#     210 def start(self) -> None:
# --> 211     self.asyncio_loop.run_forever()
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py:679, in run_forever()
#     678 while True:
# --> 679     self._run_once()
#     680     if self._stopping:
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/base_events.py:2027, in _run_once()
#    2026     else:
# -> 2027         handle._run()
#    2028 handle = None
#
# File /opt/homebrew/Cellar/python@3.13/3.13.0_1/Frameworks/Python.framework/Versions/3.13/lib/python3.13/asyncio/events.py:89, in _run()
#      88 try:
# ---> 89     self._context.run(self._callback, *self._args)
#      90 except (SystemExit, KeyboardInterrupt):
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/kernelbase.py:516, in dispatch_queue()
#     515 try:
# --> 516     await self.process_one()
#     517 except Exception:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/kernelbase.py:505, in process_one()
#     503         self.control_stream.flush()
# --> 505 await dispatch(*args)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/kernelbase.py:397, in dispatch_shell()
#     396     if inspect.isawaitable(result):
# --> 397         await result
#     398 except Exception:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/ipkernel.py:368, in execute_request()
#     367 self._associate_new_top_level_threads_with(parent_header)
# --> 368 await super().execute_request(stream, ident, parent)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/kernelbase.py:752, in execute_request()
#     751 if inspect.isawaitable(reply_content):
# --> 752     reply_content = await reply_content
#     754 # Flush output before sending the reply.
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/ipkernel.py:455, in do_execute()
#     454 if accepts_params["cell_id"]:
# --> 455     res = shell.run_cell(
#     456         code,
#     457         store_history=store_history,
#     458         silent=silent,
#     459         cell_id=cell_id,
#     460     )
#     461 else:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/ipykernel/zmqshell.py:577, in run_cell()
#     576 self._last_traceback = None
# --> 577 return super().run_cell(*args, **kwargs)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3116, in run_cell()
#    3115 try:
# -> 3116     result = self._run_cell(
#    3117         raw_cell, store_history, silent, shell_futures, cell_id
#    3118     )
#    3119 finally:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3171, in _run_cell()
#    3170 try:
# -> 3171     result = runner(coro)
#    3172 except BaseException as e:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/IPython/core/async_helpers.py:128, in _pseudo_sync_runner()
#     127 try:
# --> 128     coro.send(None)
#     129 except StopIteration as exc:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3394, in run_cell_async()
#    3391 interactivity = "none" if silent else self.ast_node_interactivity
# -> 3394 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3395        interactivity=interactivity, compiler=compiler, result=result)
#    3397 self.last_execution_succeeded = not has_raised
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3639, in run_ast_nodes()
#    3638     asy = compare(code)
# -> 3639 if await self.run_code(code, result, async_=asy):
#    3640     return True
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/IPython/core/interactiveshell.py:3699, in run_code()
#    3698     else:
# -> 3699         exec(code_obj, self.user_global_ns, self.user_ns)
#    3700 finally:
#    3701     # Reset our crash handler in place
#
# Cell In[22], line 12
#      11 samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12 _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13 all_losses.append(np.array(history["loss"]))
#
# Cell In[16], line 60, in lm_optimize_with_tracking()
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#
# Cell In[16], line 49, in loss_fn()
#      48 cov = A.T @ A
# ---> 49 return lm_loss(samples, mu, cov)
#
# Cell In[15], line 4, in lm_loss()
#       1 def lm_loss(samples, mu, cov):
# ----> 4     evolved_samples = evolve_langevin(samples, mu, cov)
#       7     return compute_sinkhorn(samples, evolved_samples)
#
# Cell In[13], line 10, in evolve_langevin()
#       9 key, subkey = jax.random.split(key)
# ---> 10 grad = potential_grad(evolved_samples, mu, cov)
#      11 noise = jax.random.normal(subkey, shape=evolved_samples.shape)
#
# Cell In[12], line 5, in potential_grad()
#       4 eps = 1e-2
# ----> 5 precision = jnp.linalg.inv(cov + eps * jnp.eye(len(mu)))
#       8 return (sample - mu) @ precision
#
# JaxStackTraceBeforeTransformation: KeyboardInterrupt
#
# The preceding stack trace is the source of the JAX operation that, once transformed by JAX, triggered the following exception.
#
# --------------------
#
# The above exception was the direct cause of the following exception:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 12
#      10 for n in tqdm(sample_sizes):
#      11     samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12     _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13     all_losses.append(np.array(history["loss"]))
#      14     all_mu_errors.append(np.array(history["mu_l2"]))
#
# Cell In[16], line 60, in lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs, base_lr, seed, eps, plot_every, use_lr_schedule)
#      52 history = {
#      53     "loss": [],
#      54     "mu_l2": [],
#      55     "cov_fro": [],
#      56 }
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#      62     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/api.py:484, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     482 _check_scalar(ans)
#     483 tree_map(partial(_check_output_dtype_grad, holomorphic), ans)
# --> 484 g = vjp_py(lax_internal._one(ans))
#     485 g = g[0] if isinstance(argnums, int) else g
#     486 if not has_aux:
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/tree_util.py:510, in _HashableCallableShim.__call__(self, *args, **kw)
#     509 def __call__(self, *args, **kw):
# --> 510   return self.fun(*args, **kw)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/api.py:2065, in _vjp_pullback_wrapper(name, out_primal_avals, io_tree, fun, *py_args_)
#    2058   if (not core.typecompat(ct_aval, ct_aval_expected) and
#    2059       not _temporary_dtype_exception(ct_aval, ct_aval_expected)):
#    2060     raise ValueError(
#    2061         "unexpected JAX type (e.g. shape/dtype) for argument to vjp function: "
#    2062         f"got {ct_aval.str_short()}, but expected {ct_aval_expected.str_short()} "
#    2063         f"because the corresponding output of the function {name} had JAX type "
#    2064         f"{aval.str_short()}")
# -> 2065 ans = fun(*args)
#    2066 return tree_unflatten(out_tree, ans)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/tree_util.py:510, in _HashableCallableShim.__call__(self, *args, **kw)
#     509 def __call__(self, *args, **kw):
# --> 510   return self.fun(*args, **kw)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:316, in vjp.<locals>.unbound_vjp(pvals, jaxpr, consts, *cts)
#     314 cts = tuple(ct for ct, pval in zip(cts, pvals) if not pval.is_known())
#     315 dummy_args = [UndefinedPrimal(v.aval) for v in jaxpr.invars]
# --> 316 arg_cts = backward_pass(jaxpr, True, consts, dummy_args, cts)
#     317 return map(instantiate_zeros, arg_cts)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:444, in backward_pass(jaxpr, transform_stack, consts, primals_in, cotangents_in)
#     442 else:
#     443   try:
# --> 444     cts_out = get_primitive_transpose(eqn.primitive)(
#     445         cts_in, *invals, **eqn.params)
#     446   except core.ShardingTypeError as e:
#     447     extra_msg = ("This is a potential JAX bug. Please file an issue at"
#     448                  " https://github.com/jax-ml/jax/issues")
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/pjit.py:2493, in _pjit_transpose(cts_in, jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *primals_in)
#    2487 transpose_out_layouts = prune_type(
#    2488     ad.Zero,
#    2489     in_layouts,
#    2490     tree_unflatten(cts_out_treedef, [object()] * cts_out_treedef.num_leaves))
#    2492 try:
# -> 2493   nz_cts_out = jit_p.bind(
#    2494       *primals_and_nz_cts_in,
#    2495       jaxpr=transpose_jaxpr,
#    2496       in_shardings=transpose_in_shardings,
#    2497       out_shardings=transpose_out_shardings,
#    2498       in_layouts=transpose_in_layouts,
#    2499       out_layouts=transpose_out_layouts,
#    2500       donated_invars=(False,) * len(primals_and_nz_cts_in),
#    2501       ctx_mesh=ctx_mesh,
#    2502       name=name,
#    2503       keep_unused=keep_unused,
#    2504       inline=inline,
#    2505       compiler_options_kvs=compiler_options_kvs)
#    2506 except api_util.InternalFloatingPointError as e:
#    2507   print("Invalid nan value encountered in the backward pass of a jax.jit "
#    2508         "function. Calling the de-optimized backward pass.")
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/core.py:576, in Primitive.bind(self, *args, **params)
#     574 def bind(self, *args, **params):
#     575   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 576   return self._true_bind(*args, **params)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/core.py:592, in Primitive._true_bind(self, *args, **params)
#     590 trace_ctx.set_trace(eval_trace)
#     591 try:
# --> 592   return self.bind_with_trace(prev_trace, args, params)
#     593 finally:
#     594   trace_ctx.set_trace(prev_trace)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/core.py:602, in Primitive.bind_with_trace(self, trace, args, params)
#     599   with set_current_trace(trace):
#     600     return self.to_lojax(*args, **params)  # type: ignore
# --> 602 return trace.process_primitive(self, args, params)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/core.py:1126, in EvalTrace.process_primitive(self, primitive, args, params)
#    1124 args = map(full_lower, args)
#    1125 check_eval_args(args)
# -> 1126 return primitive.impl(*args, **params)
#
# File ~/Desktop/codes/paper_env/lib/python3.13/site-packages/jax/_src/pjit.py:1821, in _pjit_call_impl(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, donated_invars, ctx_mesh, name, keep_unused, inline, compiler_options_kvs, *args)
#    1813 donated_argnums = tuple(i for i, d in enumerate(donated_invars) if d)
#    1814 cache_key = pxla.JitGlobalCppCacheKeys(
#    1815     donate_argnums=donated_argnums, donate_argnames=None,
#    1816     device=None, backend=None,
#    (...)   1819     in_layouts_treedef=None, in_layouts_leaves=in_layouts,
#    1820     out_layouts_treedef=None, out_layouts_leaves=out_layouts)
# -> 1821 return xc._xla.pjit(
#    1822     name, f, call_impl_cache_miss, [], [], cache_key,
#    1823     tree_util.dispatch_registry, pxla.cc_shard_arg,
#    1824     _get_cpp_global_cache(cache_key.contains_explicit_attributes))(*args)
#
# KeyboardInterrupt:

# %%
loss_matrix = np.array(all_losses)
mu_err_matrix = np.array(all_mu_errors)/np.linalg.norm(mu)
cov_err_matrix = np.array(all_cov_errors)/np.linalg.norm(cov)


steps = np.linspace(0, n_steps, n_steps)
sample_sizes = np.arange(50, 2001, 50)


def plot_heatmap(data, title, ylabel, cmap="viridis", vmin=None, vmax=None):
    plt.imshow(data, aspect="auto", origin="lower", cmap=cmap,
               extent=[steps[0], steps[-1], sample_sizes[0], sample_sizes[-1]],
               vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.xlabel("step", fontsize=13)
    plt.ylabel("n_samples", fontsize=13)
    plt.title(title, fontsize=15)


plt.figure(figsize=(18, 5))


plt.subplot(1, 3, 1)
plot_heatmap(loss_matrix, "Loss heatmap", "n_samples")


plt.subplot(1, 3, 2)
plot_heatmap(mu_err_matrix, r"$\|\mu - \hat{\mu}\|_2/\|\mu\|_2$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.subplot(1, 3, 3)
plot_heatmap(cov_err_matrix, r"$\|\Sigma - \hat{\Sigma}\|_F/\|\Sigma\|_F$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.tight_layout()
plt.show()
