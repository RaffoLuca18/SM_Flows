# %%
import jax
import jax.numpy as jnp
import optax


import matplotlib.pyplot as plt
import numpy as np


from tqdm import tqdm as tqdm
import pandas as pd


import time

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):


    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))


    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    
    return samples

# %%
def potential_grad(sample, mu, cov):


    precision = jnp.linalg.inv(cov)


    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=100, seed=0):

    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples


    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
        

    return evolved_samples

# %%
def sample_unit_directions(key, d, n_proj):


    rand = jax.random.normal(key, shape=(n_proj, d))


    return rand / jnp.linalg.norm(rand, axis=1, keepdims=True)


def sliced_wasserstein_distance(samples1, samples2, n_proj=50, p=2, key=jax.random.PRNGKey(0)):


    d = samples1.shape[1]
    directions = sample_unit_directions(key, d, n_proj)


    def proj_sort(s1, s2, dir):


        proj1 = jnp.sort(samples1 @ dir)
        proj2 = jnp.sort(samples2 @ dir)

        
        return jnp.mean(jnp.abs(proj1 - proj2) ** p)


    wasserstein_per_dir = jax.vmap(lambda dir: proj_sort(samples1, samples2, dir))(directions)


    return (jnp.mean(wasserstein_per_dir))**(1/p)

# %%
def lm_loss(samples, mu, cov):


    evolved_samples = evolve_langevin(samples, mu, cov)


    return sliced_wasserstein_distance(samples, evolved_samples)

# %%
def lm_optimize_with_tracking(
    samples,
    true_mu,
    true_cov,
    n_epochs=1000,
    base_lr=1e-2,
    seed=10,
    eps=1e-2,
    plot_every=2,
    use_lr_schedule=True
):
    

    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    if use_lr_schedule:
        lr_schedule = optax.linear_schedule(
            init_value=1e-2,
            end_value=base_lr,
            transition_steps=500
        )
        optimizer = optax.adam(learning_rate=lr_schedule)
    else:
        optimizer = optax.adam(learning_rate=base_lr)


    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    history = {
        "loss": [],
        "mu_l2": [],
        "cov_fro": [],
    }


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state, params)
        params = optax.apply_updates(params, updates)


        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val


        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov, history

# %%
mu = jnp.array([1.0])


cov = jnp.array([
[1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)


time_start = time.time()


final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=800, base_lr=0.1, seed = 0)


time_end = time.time()
time_elapsed = time_end - time_start
time_round = time_elapsed/800
print(time_round)
# Out:
# epoch 0 | loss = 0.578970
# epoch 2 | loss = 0.576082
# epoch 4 | loss = 0.573038
# epoch 6 | loss = 0.569827
# epoch 8 | loss = 0.566442
# epoch 10 | loss = 0.562871
# epoch 12 | loss = 0.559097
# epoch 14 | loss = 0.555102
# epoch 16 | loss = 0.550859
# epoch 18 | loss = 0.546334
# epoch 20 | loss = 0.541491
# epoch 22 | loss = 0.536294
# epoch 24 | loss = 0.530706
# epoch 26 | loss = 0.524695
# epoch 28 | loss = 0.518224
# epoch 30 | loss = 0.511250
# epoch 32 | loss = 0.503722
# epoch 34 | loss = 0.495570
# epoch 36 | loss = 0.486714
# epoch 38 | loss = 0.477061
# epoch 40 | loss = 0.466510
# epoch 42 | loss = 0.454957
# epoch 44 | loss = 0.442273
# epoch 46 | loss = 0.428294
# epoch 48 | loss = 0.412824
# epoch 50 | loss = 0.395648
# epoch 52 | loss = 0.376514
# epoch 54 | loss = 0.355111
# epoch 56 | loss = 0.331082
# epoch 58 | loss = 0.304001
# epoch 60 | loss = 0.273415
# epoch 62 | loss = 0.238819
# epoch 64 | loss = 0.199646
# epoch 66 | loss = 0.155474
# epoch 68 | loss = 0.106726
# epoch 70 | loss = 0.058763
# epoch 72 | loss = 0.050374
# epoch 74 | loss = 0.081904
# epoch 76 | loss = 0.097318
# epoch 78 | loss = 0.092244
# epoch 80 | loss = 0.072964
# epoch 82 | loss = 0.050794
# epoch 84 | loss = 0.045470
# epoch 86 | loss = 0.055883
# epoch 88 | loss = 0.062034
# epoch 90 | loss = 0.059398
# epoch 92 | loss = 0.051033
# epoch 94 | loss = 0.044644
# epoch 96 | loss = 0.046736
# epoch 98 | loss = 0.050760
# epoch 100 | loss = 0.049929
# epoch 102 | loss = 0.045978
# epoch 104 | loss = 0.044450
# epoch 106 | loss = 0.046165
# epoch 108 | loss = 0.047115
# epoch 110 | loss = 0.045848
# epoch 112 | loss = 0.044477
# epoch 114 | loss = 0.044806
# epoch 116 | loss = 0.045541
# epoch 118 | loss = 0.045195
# epoch 120 | loss = 0.044480
# epoch 122 | loss = 0.044530
# epoch 124 | loss = 0.044894
# epoch 126 | loss = 0.044768
# epoch 128 | loss = 0.044434
# epoch 130 | loss = 0.044465
# epoch 132 | loss = 0.044631
# epoch 134 | loss = 0.044541
# epoch 136 | loss = 0.044400
# epoch 138 | loss = 0.044453
# epoch 140 | loss = 0.044508
# epoch 142 | loss = 0.044435
# epoch 144 | loss = 0.044398
# epoch 146 | loss = 0.044442
# epoch 148 | loss = 0.044440
# epoch 150 | loss = 0.044400
# epoch 152 | loss = 0.044406
# epoch 154 | loss = 0.044423
# epoch 156 | loss = 0.044405
# epoch 158 | loss = 0.044396
# epoch 160 | loss = 0.044408
# epoch 162 | loss = 0.044405
# epoch 164 | loss = 0.044396
# epoch 166 | loss = 0.044400
# epoch 168 | loss = 0.044402
# epoch 170 | loss = 0.044396
# epoch 172 | loss = 0.044397
# epoch 174 | loss = 0.044399
# epoch 176 | loss = 0.044396
# epoch 178 | loss = 0.044396
# epoch 180 | loss = 0.044397
# epoch 182 | loss = 0.044396
# epoch 184 | loss = 0.044398
# epoch 186 | loss = 0.044415
# epoch 188 | loss = 0.044522
# epoch 190 | loss = 0.044651
# epoch 192 | loss = 0.044412
# epoch 194 | loss = 0.044509
# epoch 196 | loss = 0.044479
# epoch 198 | loss = 0.044399
# epoch 200 | loss = 0.044471
# epoch 202 | loss = 0.044433
# epoch 204 | loss = 0.044398
# epoch 206 | loss = 0.044438
# epoch 208 | loss = 0.044415
# epoch 210 | loss = 0.044398
# epoch 212 | loss = 0.044421
# epoch 214 | loss = 0.044403
# epoch 216 | loss = 0.044400
# epoch 218 | loss = 0.044410
# epoch 220 | loss = 0.044396
# epoch 222 | loss = 0.044404
# epoch 224 | loss = 0.044399
# epoch 226 | loss = 0.044398
# epoch 228 | loss = 0.044400
# epoch 230 | loss = 0.044396
# epoch 232 | loss = 0.044399
# epoch 234 | loss = 0.044396
# epoch 236 | loss = 0.044398
# epoch 238 | loss = 0.044396
# epoch 240 | loss = 0.044397
# epoch 242 | loss = 0.044396
# epoch 244 | loss = 0.044396
# epoch 246 | loss = 0.044397
# epoch 248 | loss = 0.044395
# epoch 250 | loss = 0.044396
# epoch 252 | loss = 0.044396
# epoch 254 | loss = 0.044395
# epoch 256 | loss = 0.044396
# epoch 258 | loss = 0.044396
# epoch 260 | loss = 0.044396
# epoch 262 | loss = 0.044396
# epoch 264 | loss = 0.044395
# epoch 266 | loss = 0.044395
# epoch 268 | loss = 0.044395
# epoch 270 | loss = 0.044395
# epoch 272 | loss = 0.044395
# epoch 274 | loss = 0.044396
# epoch 276 | loss = 0.044398
# epoch 278 | loss = 0.044415
# epoch 280 | loss = 0.044531
# epoch 282 | loss = 0.044968
# epoch 284 | loss = 0.044544
# epoch 286 | loss = 0.044705
# epoch 288 | loss = 0.044412
# epoch 290 | loss = 0.044644
# epoch 292 | loss = 0.044436
# epoch 294 | loss = 0.044462
# epoch 296 | loss = 0.044521
# epoch 298 | loss = 0.044399
# epoch 300 | loss = 0.044456
# epoch 302 | loss = 0.044451
# epoch 304 | loss = 0.044396
# epoch 306 | loss = 0.044441
# epoch 308 | loss = 0.044411
# epoch 310 | loss = 0.044404
# epoch 312 | loss = 0.044422
# epoch 314 | loss = 0.044396
# epoch 316 | loss = 0.044412
# epoch 318 | loss = 0.044401
# epoch 320 | loss = 0.044401
# epoch 322 | loss = 0.044403
# epoch 324 | loss = 0.044397
# epoch 326 | loss = 0.044402
# epoch 328 | loss = 0.044396
# epoch 330 | loss = 0.044400
# epoch 332 | loss = 0.044395
# epoch 334 | loss = 0.044399
# epoch 336 | loss = 0.044396
# epoch 338 | loss = 0.044397
# epoch 340 | loss = 0.044396
# epoch 342 | loss = 0.044396
# epoch 344 | loss = 0.044397
# epoch 346 | loss = 0.044395
# epoch 348 | loss = 0.044396
# epoch 350 | loss = 0.044396
# epoch 352 | loss = 0.044395
# epoch 354 | loss = 0.044396
# epoch 356 | loss = 0.044396
# epoch 358 | loss = 0.044395
# epoch 360 | loss = 0.044396
# epoch 362 | loss = 0.044396
# epoch 364 | loss = 0.044396
# epoch 366 | loss = 0.044395
# epoch 368 | loss = 0.044395
# epoch 370 | loss = 0.044395
# epoch 372 | loss = 0.044396
# epoch 374 | loss = 0.044396
# epoch 376 | loss = 0.044397
# epoch 378 | loss = 0.044399
# epoch 380 | loss = 0.044409
# epoch 382 | loss = 0.044447
# epoch 384 | loss = 0.044602
# epoch 386 | loss = 0.044970
# epoch 388 | loss = 0.044757
# epoch 390 | loss = 0.044429
# epoch 392 | loss = 0.044736
# epoch 394 | loss = 0.044401
# epoch 396 | loss = 0.044601
# epoch 398 | loss = 0.044424
# epoch 400 | loss = 0.044509
# epoch 402 | loss = 0.044438
# epoch 404 | loss = 0.044451
# epoch 406 | loss = 0.044445
# epoch 408 | loss = 0.044415
# epoch 410 | loss = 0.044445
# epoch 412 | loss = 0.044397
# epoch 414 | loss = 0.044436
# epoch 416 | loss = 0.044398
# epoch 418 | loss = 0.044416
# epoch 420 | loss = 0.044409
# epoch 422 | loss = 0.044398
# epoch 424 | loss = 0.044412
# epoch 426 | loss = 0.044398
# epoch 428 | loss = 0.044399
# epoch 430 | loss = 0.044405
# epoch 432 | loss = 0.044397
# epoch 434 | loss = 0.044397
# epoch 436 | loss = 0.044401
# epoch 438 | loss = 0.044399
# epoch 440 | loss = 0.044396
# epoch 442 | loss = 0.044396
# epoch 444 | loss = 0.044399
# epoch 446 | loss = 0.044399
# epoch 448 | loss = 0.044399
# epoch 450 | loss = 0.044397
# epoch 452 | loss = 0.044397
# epoch 454 | loss = 0.044396
# epoch 456 | loss = 0.044396
# epoch 458 | loss = 0.044397
# epoch 460 | loss = 0.044400
# epoch 462 | loss = 0.044411
# epoch 464 | loss = 0.044455
# epoch 466 | loss = 0.044627
# epoch 468 | loss = 0.045090
# epoch 470 | loss = 0.045090
# epoch 472 | loss = 0.044400
# epoch 474 | loss = 0.044792
# epoch 476 | loss = 0.044576
# epoch 478 | loss = 0.044492
# epoch 480 | loss = 0.044632
# epoch 482 | loss = 0.044399
# epoch 484 | loss = 0.044574
# epoch 486 | loss = 0.044409
# epoch 488 | loss = 0.044485
# epoch 490 | loss = 0.044445
# epoch 492 | loss = 0.044416
# epoch 494 | loss = 0.044461
# epoch 496 | loss = 0.044396
# epoch 498 | loss = 0.044436
# epoch 500 | loss = 0.044415
# epoch 502 | loss = 0.044400
# epoch 504 | loss = 0.044423
# epoch 506 | loss = 0.044399
# epoch 508 | loss = 0.044403
# epoch 510 | loss = 0.044409
# epoch 512 | loss = 0.044396
# epoch 514 | loss = 0.044402
# epoch 516 | loss = 0.044402
# epoch 518 | loss = 0.044395
# epoch 520 | loss = 0.044399
# epoch 522 | loss = 0.044399
# epoch 524 | loss = 0.044395
# epoch 526 | loss = 0.044397
# epoch 528 | loss = 0.044398
# epoch 530 | loss = 0.044396
# epoch 532 | loss = 0.044396
# epoch 534 | loss = 0.044397
# epoch 536 | loss = 0.044396
# epoch 538 | loss = 0.044395
# epoch 540 | loss = 0.044396
# epoch 542 | loss = 0.044396
# epoch 544 | loss = 0.044395
# epoch 546 | loss = 0.044395
# epoch 548 | loss = 0.044396
# epoch 550 | loss = 0.044396
# epoch 552 | loss = 0.044395
# epoch 554 | loss = 0.044395
# epoch 556 | loss = 0.044395
# epoch 558 | loss = 0.044396
# epoch 560 | loss = 0.044395
# epoch 562 | loss = 0.044395
# epoch 564 | loss = 0.044395
# epoch 566 | loss = 0.044395
# epoch 568 | loss = 0.044395
# epoch 570 | loss = 0.044395
# epoch 572 | loss = 0.044395
# epoch 574 | loss = 0.044395
# epoch 576 | loss = 0.044395
# epoch 578 | loss = 0.044395
# epoch 580 | loss = 0.044395
# epoch 582 | loss = 0.044395
# epoch 584 | loss = 0.044395
# epoch 586 | loss = 0.044395
# epoch 588 | loss = 0.044395
# epoch 590 | loss = 0.044395
# epoch 592 | loss = 0.044395
# epoch 594 | loss = 0.044395
# epoch 596 | loss = 0.044395
# epoch 598 | loss = 0.044395
# epoch 600 | loss = 0.044396
# epoch 602 | loss = 0.044396
# epoch 604 | loss = 0.044398
# epoch 606 | loss = 0.044403
# epoch 608 | loss = 0.044419
# epoch 610 | loss = 0.044472
# epoch 612 | loss = 0.044632
# epoch 614 | loss = 0.044946
# epoch 616 | loss = 0.044965
# epoch 618 | loss = 0.044468
# epoch 620 | loss = 0.044506
# epoch 622 | loss = 0.044690
# epoch 624 | loss = 0.044433
# epoch 626 | loss = 0.044476
# epoch 628 | loss = 0.044541
# epoch 630 | loss = 0.044398
# epoch 632 | loss = 0.044469
# epoch 634 | loss = 0.044454
# epoch 636 | loss = 0.044398
# epoch 638 | loss = 0.044449
# epoch 640 | loss = 0.044413
# epoch 642 | loss = 0.044403
# epoch 644 | loss = 0.044426
# epoch 646 | loss = 0.044399
# epoch 648 | loss = 0.044404
# epoch 650 | loss = 0.044411
# epoch 652 | loss = 0.044396
# epoch 654 | loss = 0.044402
# epoch 656 | loss = 0.044404
# epoch 658 | loss = 0.044396
# epoch 660 | loss = 0.044399
# epoch 662 | loss = 0.044400
# epoch 664 | loss = 0.044396
# epoch 666 | loss = 0.044397
# epoch 668 | loss = 0.044398
# epoch 670 | loss = 0.044396
# epoch 672 | loss = 0.044396
# epoch 674 | loss = 0.044397
# epoch 676 | loss = 0.044396
# epoch 678 | loss = 0.044395
# epoch 680 | loss = 0.044396
# epoch 682 | loss = 0.044396
# epoch 684 | loss = 0.044395
# epoch 686 | loss = 0.044395
# epoch 688 | loss = 0.044396
# epoch 690 | loss = 0.044396
# epoch 692 | loss = 0.044395
# epoch 694 | loss = 0.044395
# epoch 696 | loss = 0.044395
# epoch 698 | loss = 0.044396
# epoch 700 | loss = 0.044395
# epoch 702 | loss = 0.044395
# epoch 704 | loss = 0.044395
# epoch 706 | loss = 0.044395
# epoch 708 | loss = 0.044395
# epoch 710 | loss = 0.044395
# epoch 712 | loss = 0.044395
# epoch 714 | loss = 0.044395
# epoch 716 | loss = 0.044395
# epoch 718 | loss = 0.044395
# epoch 720 | loss = 0.044395
# epoch 722 | loss = 0.044395
# epoch 724 | loss = 0.044395
# epoch 726 | loss = 0.044395
# epoch 728 | loss = 0.044395
# epoch 730 | loss = 0.044395
# epoch 732 | loss = 0.044395
# epoch 734 | loss = 0.044395
# epoch 736 | loss = 0.044395
# epoch 738 | loss = 0.044395
# epoch 740 | loss = 0.044395
# epoch 742 | loss = 0.044395
# epoch 744 | loss = 0.044395
# epoch 746 | loss = 0.044395
# epoch 748 | loss = 0.044395
# epoch 750 | loss = 0.044396
# epoch 752 | loss = 0.044396
# epoch 754 | loss = 0.044396
# epoch 756 | loss = 0.044398
# epoch 758 | loss = 0.044404
# epoch 760 | loss = 0.044423
# epoch 762 | loss = 0.044480
# epoch 764 | loss = 0.044641
# epoch 766 | loss = 0.044941
# epoch 768 | loss = 0.044980
# epoch 770 | loss = 0.044508
# epoch 772 | loss = 0.044456
# epoch 774 | loss = 0.044685
# epoch 776 | loss = 0.044499
# epoch 778 | loss = 0.044416
# epoch 780 | loss = 0.044548
# epoch 782 | loss = 0.044445
# epoch 784 | loss = 0.044412
# epoch 786 | loss = 0.044480
# epoch 788 | loss = 0.044415
# epoch 790 | loss = 0.044409
# epoch 792 | loss = 0.044442
# epoch 794 | loss = 0.044403
# epoch 796 | loss = 0.044405
# epoch 798 | loss = 0.044421
# epoch 799 | loss = 0.044411
# 0.19737887531518936

# %%
jnp.set_printoptions(precision=4, suppress=True)


print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu)/jnp.linalg.norm(mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov)/jnp.linalg.norm(cov), "\n\n\n")
# Out:
# [1.]
#
#  [0.9475] 0.052541196
#
#
#
# [[1.]]
#
#  [[0.9777]] 0.022346973

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="score matching loss")
plt.xlabel("step", fontsize=14)
plt.ylabel("loss", fontsize=14)
plt.title("loss evolution", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"]/np.linalg.norm(mu), label=r"$\| \mu - \hat{\mu} \|_2/\|\mu\|\_2$")
plt.plot(history_np["cov_fro"]/np.linalg.norm(cov), label=r"$\| \Sigma - \hat{\Sigma} \|_F/\|\Sigma\|_F$")
plt.yscale("log")
plt.xlabel("step", fontsize=14)
plt.title("reconstruction error", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.tight_layout()
plt.show()

# %%
sample_sizes = np.arange(50, 2001, 50)
n_steps = 800


all_losses = []
all_mu_errors = []
all_cov_errors = []


for n in tqdm(sample_sizes):
    samples = generate_gaussian_samples(mu, cov, n, seed=0)
    _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
    all_losses.append(np.array(history["loss"]))
    all_mu_errors.append(np.array(history["mu_l2"]))
    all_cov_errors.append(np.array(history["cov_fro"]))
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# epoch 0 | loss = 0.428195
# epoch 2 | loss = 0.425801
# epoch 4 | loss = 0.423286
# epoch 6 | loss = 0.420645
#   0%|          | 0/40 [00:02<?, ?it/s]
# epoch 8 | loss = 0.417879
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 12
#      10 for n in tqdm(sample_sizes):
#      11     samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12     _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13     all_losses.append(np.array(history["loss"]))
#      14     all_mu_errors.append(np.array(history["mu_l2"]))
#
# Cell In[7], line 60, in lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs, base_lr, seed, eps, plot_every, use_lr_schedule)
#      52 history = {
#      53     "loss": [],
#      54     "mu_l2": [],
#      55     "cov_fro": [],
#      56 }
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#      62     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:479, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     477   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     478 if not has_aux:
# --> 479   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     480 else:
#     481   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:2143, in _vjp(fun, has_aux, *primals)
#    2141 if not has_aux:
#    2142   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2143   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2144   out_tree = out_tree()
#    2145 else:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:309, in vjp(traceable, primals, has_aux)
#     307 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     308   if not has_aux:
# --> 309     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     310   else:
#     311     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:283, in linearize(traceable, *primals, **kwargs)
#     281 has_aux = kwargs.pop('has_aux', False)
#     282 if config.use_direct_linearize.value:
# --> 283   return direct_linearize(traceable, primals, kwargs, has_aux=has_aux)
#     284 if not has_aux:
#     285   jvpfun = jvp(traceable)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:256, in direct_linearize(traceable, primals, kwargs, has_aux, tag)
#     251   aux_primals = [x.primal
#     252                  if isinstance(x, LinearizeTracer)
#     253                  and x._trace.tag is linearize_trace.tag
#     254                  else x for x in aux]
#     255 else:
# --> 256   ans = traceable.call_wrapped(*tracers)
#     257   aux = None
#     258 out_primals, out_tangents = unzip2(map(linearize_trace.to_primal_tangent_pair, ans))
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# Cell In[7], line 49, in lm_optimize_with_tracking.<locals>.loss_fn(params, samples)
#      47 A = params["A"]
#      48 cov = A.T @ A
# ---> 49 return lm_loss(samples, mu, cov)
#
# Cell In[6], line 4, in lm_loss(samples, mu, cov)
#       1 def lm_loss(samples, mu, cov):
# ----> 4     evolved_samples = evolve_langevin(samples, mu, cov)
#       7     return sliced_wasserstein_distance(samples, evolved_samples)
#
# Cell In[4], line 10, in evolve_langevin(samples, mu, cov, eps, n_evolution, seed)
#       8 for i in range(n_evolution):
#       9     key, subkey = jax.random.split(key)
# ---> 10     grad = potential_grad(evolved_samples, mu, cov)
#      11     noise = jax.random.normal(subkey, shape=evolved_samples.shape)
#      12     evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
#
# Cell In[3], line 7, in potential_grad(sample, mu, cov)
#       1 def potential_grad(sample, mu, cov):
#       4     precision = jnp.linalg.inv(cov)
# ----> 7     return (sample - mu) @ precision
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1125, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1124 def op(self, *args):
# -> 1125   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:586, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     584 args = (other, self) if swap else (self, other)
#     585 if isinstance(other, _accepted_binop_types):
# --> 586   return binary_op(*args)
#     587 # Note: don't use isinstance here, because we don't want to raise for
#     588 # subclasses, e.g. NamedTuple objects that may override operators.
#     589 if type(other) in _rejected_binop_types:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/numpy/ufunc_api.py:183, in ufunc.__call__(self, out, where, *args)
#     181   raise NotImplementedError(f"where argument of {self}")
#     182 call = self.__static_props['call'] or self._call_vectorized
# --> 183 return call(*args)
#
# KeyboardInterrupt:

# %%
loss_matrix = np.array(all_losses)
mu_err_matrix = np.array(all_mu_errors)/np.linalg.norm(mu)
cov_err_matrix = np.array(all_cov_errors)/np.linalg.norm(cov)


steps = np.linspace(0, n_steps, n_steps)
sample_sizes = np.arange(50, 2001, 50)


def plot_heatmap(data, title, ylabel, cmap="viridis", vmin=None, vmax=None):
    plt.imshow(data, aspect="auto", origin="lower", cmap=cmap,
               extent=[steps[0], steps[-1], sample_sizes[0], sample_sizes[-1]],
               vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.xlabel("step", fontsize=13)
    plt.ylabel("n_samples", fontsize=13)
    plt.title(title, fontsize=15)


plt.figure(figsize=(18, 5))


plt.subplot(1, 3, 1)
plot_heatmap(loss_matrix, "Loss heatmap", "n_samples")


plt.subplot(1, 3, 2)
plot_heatmap(mu_err_matrix, r"$\|\mu - \hat{\mu}\|_2/\|\mu\|_2$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.subplot(1, 3, 3)
plot_heatmap(cov_err_matrix, r"$\|\Sigma - \hat{\Sigma}\|_F/\|\Sigma\|_F$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.tight_layout()
plt.show()
