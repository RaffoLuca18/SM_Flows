# %%
import jax
import jax.numpy as jnp
import optax


import matplotlib.pyplot as plt
import numpy as np


from tqdm import tqdm as tqdm
import pandas as pd


import time

# %%
def generate_gaussian_samples(mu, cov, n_samples, seed=0):


    d = mu.shape[0]
    key = jax.random.PRNGKey(seed)
    z = jax.random.normal(key, shape=(n_samples, d))


    L = jnp.linalg.cholesky(cov)
    samples = mu + z @ L.T
    
    
    return samples

# %%
def potential_grad(sample, mu, cov):


    precision = jnp.linalg.inv(cov)


    return (sample - mu) @ precision

# %%
def evolve_langevin(samples, mu, cov, eps=1e-2, n_evolution=100, seed=0):

    
    key = jax.random.PRNGKey(seed)
    evolved_samples = samples


    for i in range(n_evolution):
        key, subkey = jax.random.split(key)
        grad = potential_grad(evolved_samples, mu, cov)
        noise = jax.random.normal(subkey, shape=evolved_samples.shape)
        evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
        

    return evolved_samples

# %%
def sample_unit_directions(key, d, n_proj):


    rand = jax.random.normal(key, shape=(n_proj, d))

    
    return rand / jnp.linalg.norm(rand, axis=1, keepdims=True)


def sliced_wasserstein_distance(samples1, samples2, n_proj=100, p=2, key=jax.random.PRNGKey(0)):


    d = samples1.shape[1]
    directions = sample_unit_directions(key, d, n_proj)


    def proj_sort(s1, s2, dir):


        proj1 = jnp.sort(samples1 @ dir)
        proj2 = jnp.sort(samples2 @ dir)


        return jnp.mean(jnp.abs(proj1 - proj2) ** p)


    wasserstein_per_dir = jax.vmap(lambda dir: proj_sort(samples1, samples2, dir))(directions)


    return (jnp.mean(wasserstein_per_dir))**(1/p)

# %%
def lm_loss(samples, mu, cov):


    evolved_samples = evolve_langevin(samples, mu, cov)


    return sliced_wasserstein_distance(samples, evolved_samples)

# %%
def lm_optimize_with_tracking(
    samples,
    true_mu,
    true_cov,
    n_epochs=1000,
    base_lr=1e-2,
    seed=10,
    eps=1e-2,
    plot_every=2,
    use_lr_schedule=True
):
    

    n, d = samples.shape


    key = jax.random.PRNGKey(seed)
    key_mu, key_A = jax.random.split(key)


    mu = jax.random.normal(key_mu, shape=(d,))
    A = jax.random.normal(key_A, shape=(d, d))


    params = {
        "mu": mu,
        "A": A
    }


    if use_lr_schedule:
        lr_schedule = optax.linear_schedule(
            init_value=1e-2,
            end_value=base_lr,
            transition_steps=500
        )
        optimizer = optax.adam(learning_rate=lr_schedule)
    else:
        optimizer = optax.adam(learning_rate=base_lr)


    opt_state = optimizer.init(params)


    def loss_fn(params, samples):
        mu = params["mu"]
        A = params["A"]
        cov = A.T @ A
        return lm_loss(samples, mu, cov)


    history = {
        "loss": [],
        "mu_l2": [],
        "cov_fro": [],
    }


    for epoch in range(n_epochs):
        loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
        updates, opt_state = optimizer.update(grads, opt_state, params)
        params = optax.apply_updates(params, updates)


        mu_val = params["mu"]
        A_val = params["A"]
        cov_val = A_val.T @ A_val


        history["loss"].append(loss_val)
        history["mu_l2"].append(jnp.linalg.norm(true_mu - mu_val))
        history["cov_fro"].append(jnp.linalg.norm(true_cov - cov_val, ord='fro'))


        if epoch % plot_every == 0 or epoch == n_epochs - 1:
            print(f"epoch {epoch} | loss = {loss_val:.6f}")


    final_mu = params["mu"]
    final_cov = params["A"].T @ params["A"]


    return final_mu, final_cov, history

# %%
mu = jnp.array([0.0, 1.0, -1.0, 0.5, -0.5])


cov = jnp.array([
    [1.0, 0.4, 0.3, 0.2, 0.1],
    [0.4, 1.0, 0.5, 0.3, 0.2],
    [0.3, 0.5, 1.0, 0.4, 0.3],
    [0.2, 0.3, 0.4, 1.0, 0.5],
    [0.1, 0.2, 0.3, 0.5, 1.0]
])

# %%
samples = generate_gaussian_samples(mu, cov, n_samples=2000, seed=0)


time_start = time.time()


final_mu, final_cov, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=800, base_lr=0.1, seed = 0)


time_end = time.time()
time_elapsed = time_end - time_start
time_round = time_elapsed/800
print(time_round)
# Out:
# epoch 0 | loss = 0.549480
# epoch 2 | loss = 0.533819
# epoch 4 | loss = 0.521499
# epoch 6 | loss = 0.511913
# epoch 8 | loss = 0.503858
# epoch 10 | loss = 0.496348
# epoch 12 | loss = 0.488972
# epoch 14 | loss = 0.481645
# epoch 16 | loss = 0.474367
# epoch 18 | loss = 0.467085
# epoch 20 | loss = 0.459651
# epoch 22 | loss = 0.451884
# epoch 24 | loss = 0.443668
# epoch 26 | loss = 0.435010
# epoch 28 | loss = 0.426057
# epoch 30 | loss = 0.417108
# epoch 32 | loss = 0.408614
# epoch 34 | loss = 0.401166
# epoch 36 | loss = 0.395324
# epoch 38 | loss = 0.391265
# epoch 40 | loss = 0.388500
# epoch 42 | loss = 0.386091
# epoch 44 | loss = 0.383239
# epoch 46 | loss = 0.379579
# epoch 48 | loss = 0.375016
# epoch 50 | loss = 0.369600
# epoch 52 | loss = 0.363433
# epoch 54 | loss = 0.356618
# epoch 56 | loss = 0.349238
# epoch 58 | loss = 0.341343
# epoch 60 | loss = 0.333065
# epoch 62 | loss = 0.324843
# epoch 64 | loss = 0.317518
# epoch 66 | loss = 0.311914
# epoch 68 | loss = 0.307890
# epoch 70 | loss = 0.304742
# epoch 72 | loss = 0.302409
# epoch 74 | loss = 0.300575
# epoch 76 | loss = 0.298586
# epoch 78 | loss = 0.296449
# epoch 80 | loss = 0.293864
# epoch 82 | loss = 0.290429
# epoch 84 | loss = 0.286365
# epoch 86 | loss = 0.281750
# epoch 88 | loss = 0.276623
# epoch 90 | loss = 0.271003
# epoch 92 | loss = 0.264513
# epoch 94 | loss = 0.256567
# epoch 96 | loss = 0.246495
# epoch 98 | loss = 0.233445
# epoch 100 | loss = 0.216711
# epoch 102 | loss = 0.196880
# epoch 104 | loss = 0.178816
# epoch 106 | loss = 0.170845
# epoch 108 | loss = 0.166942
# epoch 110 | loss = 0.154782
# epoch 112 | loss = 0.137116
# epoch 114 | loss = 0.121166
# epoch 116 | loss = 0.108239
# epoch 118 | loss = 0.098191
# epoch 120 | loss = 0.089263
# epoch 122 | loss = 0.080218
# epoch 668 | loss = 0.040790
# epoch 670 | loss = 0.040694
# epoch 672 | loss = 0.040652
# epoch 674 | loss = 0.040638
# epoch 676 | loss = 0.040642
# epoch 678 | loss = 0.040663
# epoch 680 | loss = 0.040719
# epoch 682 | loss = 0.040833
# epoch 684 | loss = 0.041023
# epoch 686 | loss = 0.041207
# epoch 688 | loss = 0.041278
# epoch 690 | loss = 0.041158
# epoch 692 | loss = 0.040929
# epoch 694 | loss = 0.040755
# epoch 696 | loss = 0.040670
# epoch 698 | loss = 0.040637
# epoch 700 | loss = 0.040627
# epoch 702 | loss = 0.040631
# epoch 704 | loss = 0.040651
# epoch 706 | loss = 0.040698
# epoch 708 | loss = 0.040797
# epoch 710 | loss = 0.040980
# epoch 712 | loss = 0.041213
# epoch 714 | loss = 0.041350
# epoch 716 | loss = 0.041259
# epoch 718 | loss = 0.041008
# epoch 720 | loss = 0.040777
# epoch 722 | loss = 0.040662
# epoch 724 | loss = 0.040621
# epoch 726 | loss = 0.040609
# epoch 728 | loss = 0.040606
# epoch 730 | loss = 0.040605
# epoch 732 | loss = 0.040605
# epoch 734 | loss = 0.040606
# epoch 736 | loss = 0.040606
# epoch 738 | loss = 0.040607
# epoch 740 | loss = 0.040612
# epoch 742 | loss = 0.040630
# epoch 744 | loss = 0.040691
# epoch 746 | loss = 0.040871
# epoch 748 | loss = 0.041275
# epoch 750 | loss = 0.041818
# epoch 752 | loss = 0.041853
# epoch 754 | loss = 0.041275
# epoch 756 | loss = 0.040802
# epoch 758 | loss = 0.040627
# epoch 760 | loss = 0.040612
# epoch 762 | loss = 0.040678
# epoch 764 | loss = 0.040829
# epoch 766 | loss = 0.041067
# epoch 768 | loss = 0.041268
# epoch 770 | loss = 0.041269
# epoch 772 | loss = 0.041065
# epoch 774 | loss = 0.040822
# epoch 776 | loss = 0.040684
# epoch 778 | loss = 0.040628
# epoch 780 | loss = 0.040610
# epoch 782 | loss = 0.040606
# epoch 784 | loss = 0.040607
# epoch 786 | loss = 0.040613
# epoch 788 | loss = 0.040631
# epoch 790 | loss = 0.040677
# epoch 792 | loss = 0.040786
# epoch 794 | loss = 0.041012
# epoch 796 | loss = 0.041323
# epoch 798 | loss = 0.041504
# epoch 799 | loss = 0.041436
# 0.2467500677704811

# %%
jnp.set_printoptions(precision=4, suppress=True)


print(jnp.round(mu, 4), "\n\n", jnp.round(final_mu, 4), jnp.linalg.norm(mu - final_mu)/jnp.linalg.norm(mu), "\n\n\n")
print(jnp.round(cov, 4), "\n\n", jnp.round(final_cov, 4), jnp.linalg.norm(cov - final_cov)/jnp.linalg.norm(cov), "\n\n\n")
# Out:
# [ 0.   1.  -1.   0.5 -0.5]
#
#  [ 0.061   1.0434 -0.9117  0.5017 -0.4657] 0.07634726
#
#
#
# [[1.  0.4 0.3 0.2 0.1]
#  [0.4 1.  0.5 0.3 0.2]
#  [0.3 0.5 1.  0.4 0.3]
#  [0.2 0.3 0.4 1.  0.5]
#  [0.1 0.2 0.3 0.5 1. ]]
#
#  [[0.9702 0.3653 0.2445 0.1224 0.055 ]
#  [0.3653 1.0011 0.4667 0.2748 0.1857]
#  [0.2445 0.4667 1.0383 0.4046 0.387 ]
#  [0.1224 0.2748 0.4046 1.0435 0.4731]
#  [0.055  0.1857 0.387  0.4731 1.0703]] 0.08597686

# %%
history_np = {k: np.array(v) for k, v in history.items()}

# %%
plt.figure(figsize=(12, 6))


plt.subplot(1, 2, 1)
plt.plot(history_np["loss"], label="score matching loss")
plt.xlabel("step", fontsize=14)
plt.ylabel("loss", fontsize=14)
plt.title("loss evolution", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.subplot(1, 2, 2)
plt.plot(history_np["mu_l2"]/np.linalg.norm(mu), label=r"$\| \mu - \hat{\mu} \|_2/\|\mu\|\_2$")
plt.plot(history_np["cov_fro"]/np.linalg.norm(cov), label=r"$\| \Sigma - \hat{\Sigma} \|_F/\|\Sigma\|_F$")
plt.yscale("log")
plt.xlabel("step", fontsize=14)
plt.title("reconstruction error", fontsize=16)
plt.grid(True)
plt.legend(fontsize=12)


plt.tight_layout()
plt.show()

# %%
sample_sizes = np.arange(50, 2001, 50)
n_steps = 800


all_losses = []
all_mu_errors = []
all_cov_errors = []


for n in tqdm(sample_sizes):
    samples = generate_gaussian_samples(mu, cov, n, seed=0)
    _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
    all_losses.append(np.array(history["loss"]))
    all_mu_errors.append(np.array(history["mu_l2"]))
    all_cov_errors.append(np.array(history["cov_fro"]))
# Out:
#   0%|          | 0/40 [00:00<?, ?it/s]
# epoch 0 | loss = 0.539161
# epoch 2 | loss = 0.525038
# epoch 4 | loss = 0.512887
# epoch 6 | loss = 0.502142
# epoch 8 | loss = 0.492432
# epoch 10 | loss = 0.483371
# epoch 12 | loss = 0.474510
# epoch 14 | loss = 0.465525
# epoch 16 | loss = 0.456183
# epoch 18 | loss = 0.446395
# epoch 20 | loss = 0.436150
# epoch 22 | loss = 0.425443
# epoch 24 | loss = 0.414346
# epoch 26 | loss = 0.403038
# epoch 28 | loss = 0.391942
# epoch 30 | loss = 0.381595
# epoch 32 | loss = 0.372471
# epoch 34 | loss = 0.365077
# epoch 36 | loss = 0.359626
# epoch 38 | loss = 0.355849
# epoch 40 | loss = 0.352879
# epoch 42 | loss = 0.349850
# epoch 44 | loss = 0.346136
# epoch 46 | loss = 0.341527
# epoch 48 | loss = 0.336157
# epoch 50 | loss = 0.330317
# epoch 52 | loss = 0.324484
# epoch 54 | loss = 0.318795
# epoch 56 | loss = 0.313029
# epoch 58 | loss = 0.306976
# epoch 60 | loss = 0.300502
# epoch 62 | loss = 0.293305
# epoch 64 | loss = 0.285346
# epoch 66 | loss = 0.276918
# epoch 68 | loss = 0.268424
# epoch 70 | loss = 0.261038
# epoch 72 | loss = 0.256345
# epoch 74 | loss = 0.254329
# epoch 76 | loss = 0.253741
# epoch 78 | loss = 0.251571
# epoch 80 | loss = 0.247519
# epoch 82 | loss = 0.244740
# epoch 266 | loss = 0.194012
# epoch 268 | loss = 0.194007
# epoch 270 | loss = 0.194003
# epoch 272 | loss = 0.194006
# epoch 274 | loss = 0.194002
# epoch 276 | loss = 0.194000
# epoch 278 | loss = 0.193998
# epoch 280 | loss = 0.194000
# epoch 282 | loss = 0.193995
# epoch 284 | loss = 0.193995
# epoch 286 | loss = 0.193996
# epoch 288 | loss = 0.193996
# epoch 290 | loss = 0.193994
# epoch 292 | loss = 0.193994
# epoch 294 | loss = 0.193992
# epoch 296 | loss = 0.193994
# epoch 298 | loss = 0.193992
# epoch 300 | loss = 0.193992
# epoch 302 | loss = 0.193993
# epoch 304 | loss = 0.193992
# epoch 306 | loss = 0.193997
# epoch 308 | loss = 0.194004
# epoch 310 | loss = 0.193992
# epoch 312 | loss = 0.194006
# epoch 314 | loss = 0.193999
# epoch 316 | loss = 0.193999
# epoch 318 | loss = 0.194004
# epoch 320 | loss = 0.193994
# epoch 322 | loss = 0.193993
# epoch 324 | loss = 0.193999
# epoch 326 | loss = 0.193995
# epoch 328 | loss = 0.193996
# epoch 330 | loss = 0.193993
# epoch 332 | loss = 0.193995
# epoch 334 | loss = 0.193996
# epoch 336 | loss = 0.193993
# epoch 338 | loss = 0.194015
# epoch 340 | loss = 0.193995
# epoch 342 | loss = 0.194017
# epoch 344 | loss = 0.194003
# epoch 346 | loss = 0.194011
# epoch 348 | loss = 0.194001
# epoch 350 | loss = 0.194007
# epoch 352 | loss = 0.194007
# epoch 354 | loss = 0.194000
# epoch 356 | loss = 0.194002
#   0%|          | 0/40 [00:55<?, ?it/s]
# epoch 358 | loss = 0.194000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 12
#      10 for n in tqdm(sample_sizes):
#      11     samples = generate_gaussian_samples(mu, cov, n, seed=0)
# ---> 12     _, _, history = lm_optimize_with_tracking(samples, mu, cov, n_epochs=n_steps, base_lr=0.1, seed = 0)
#      13     all_losses.append(np.array(history["loss"]))
#      14     all_mu_errors.append(np.array(history["mu_l2"]))
#
# Cell In[7], line 60, in lm_optimize_with_tracking(samples, true_mu, true_cov, n_epochs, base_lr, seed, eps, plot_every, use_lr_schedule)
#      52 history = {
#      53     "loss": [],
#      54     "mu_l2": [],
#      55     "cov_fro": [],
#      56 }
#      59 for epoch in range(n_epochs):
# ---> 60     loss_val, grads = jax.value_and_grad(loss_fn)(params, samples)
#      61     updates, opt_state = optimizer.update(grads, opt_state, params)
#      62     params = optax.apply_updates(params, updates)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:479, in value_and_grad.<locals>.value_and_grad_f(*args, **kwargs)
#     477   _check_input_dtype_grad(holomorphic, allow_int, leaf)
#     478 if not has_aux:
# --> 479   ans, vjp_py = _vjp(f_partial, *dyn_args)
#     480 else:
#     481   ans, vjp_py, aux = _vjp(f_partial, *dyn_args, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api.py:2143, in _vjp(fun, has_aux, *primals)
#    2141 if not has_aux:
#    2142   flat_fun, out_tree = flatten_fun_nokwargs(fun, in_tree)
# -> 2143   out_primals, vjp = ad.vjp(flat_fun, primals_flat)
#    2144   out_tree = out_tree()
#    2145 else:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:309, in vjp(traceable, primals, has_aux)
#     307 def vjp(traceable: lu.WrappedFun, primals, has_aux=False):
#     308   if not has_aux:
# --> 309     out_primals, pvals, jaxpr, consts = linearize(traceable, *primals)
#     310   else:
#     311     out_primals, pvals, jaxpr, consts, aux = linearize(traceable, *primals, has_aux=True)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:283, in linearize(traceable, *primals, **kwargs)
#     281 has_aux = kwargs.pop('has_aux', False)
#     282 if config.use_direct_linearize.value:
# --> 283   return direct_linearize(traceable, primals, kwargs, has_aux=has_aux)
#     284 if not has_aux:
#     285   jvpfun = jvp(traceable)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:256, in direct_linearize(traceable, primals, kwargs, has_aux, tag)
#     251   aux_primals = [x.primal
#     252                  if isinstance(x, LinearizeTracer)
#     253                  and x._trace.tag is linearize_trace.tag
#     254                  else x for x in aux]
#     255 else:
# --> 256   ans = traceable.call_wrapped(*tracers)
#     257   aux = None
#     258 out_primals, out_tangents = unzip2(map(linearize_trace.to_primal_tangent_pair, ans))
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:212, in WrappedFun.call_wrapped(self, *args, **kwargs)
#     210 def call_wrapped(self, *args, **kwargs):
#     211   """Calls the transformed function"""
# --> 212   return self.f_transformed(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:90, in flatten_fun_nokwargs(f, store, in_tree, *args_flat)
#      86 @lu.transformation_with_aux2
#      87 def flatten_fun_nokwargs(f: Callable, store: lu.Store,
#      88                          in_tree: PyTreeDef, *args_flat):
#      89   py_args = tree_unflatten(in_tree, args_flat)
# ---> 90   ans = f(*py_args)
#      91   ans, out_tree = tree_flatten(ans)
#      92   store.store(out_tree)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/api_util.py:288, in _argnums_partial(_fun, _dyn_argnums, _fixed_args, *dyn_args, **kwargs)
#     286 args = [next(fixed_args_).val if x is sentinel else x for x in args]
#     287 assert next(fixed_args_, sentinel) is sentinel
# --> 288 return _fun(*args, **kwargs)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/linear_util.py:397, in _get_result_paths_thunk(_fun, _store, *args, **kwargs)
#     395 @transformation_with_aux2
#     396 def _get_result_paths_thunk(_fun: Callable, _store: Store, *args, **kwargs):
# --> 397   ans = _fun(*args, **kwargs)
#     398   result_paths = tuple(f"result{_clean_keystr_arg_names(path)}" for path, _ in generate_key_paths(ans))
#     399   if _store:
#     400     # In some instances a lu.WrappedFun is called multiple times, e.g.,
#     401     # the bwd function in a custom_vjp
#
# Cell In[7], line 49, in lm_optimize_with_tracking.<locals>.loss_fn(params, samples)
#      47 A = params["A"]
#      48 cov = A.T @ A
# ---> 49 return lm_loss(samples, mu, cov)
#
# Cell In[6], line 4, in lm_loss(samples, mu, cov)
#       1 def lm_loss(samples, mu, cov):
# ----> 4     evolved_samples = evolve_langevin(samples, mu, cov)
#       7     return sliced_wasserstein_distance(samples, evolved_samples)
#
# Cell In[4], line 10, in evolve_langevin(samples, mu, cov, eps, n_evolution, seed)
#       8 for i in range(n_evolution):
#       9     key, subkey = jax.random.split(key)
# ---> 10     grad = potential_grad(evolved_samples, mu, cov)
#      11     noise = jax.random.normal(subkey, shape=evolved_samples.shape)
#      12     evolved_samples = evolved_samples - eps * grad + jnp.sqrt(2 * eps) * noise
#
# Cell In[3], line 7, in potential_grad(sample, mu, cov)
#       1 def potential_grad(sample, mu, cov):
#       4     precision = jnp.linalg.inv(cov)
# ----> 7     return (sample - mu) @ precision
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:1125, in _forward_operator_to_aval.<locals>.op(self, *args)
#    1124 def op(self, *args):
# -> 1125   return getattr(self.aval, f"_{name}")(self, *args)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/numpy/array_methods.py:586, in _defer_to_unrecognized_arg.<locals>.deferring_binary_op(self, other)
#     584 args = (other, self) if swap else (self, other)
#     585 if isinstance(other, _accepted_binop_types):
# --> 586   return binary_op(*args)
#     587 # Note: don't use isinstance here, because we don't want to raise for
#     588 # subclasses, e.g. NamedTuple objects that may override operators.
#     589 if type(other) in _rejected_binop_types:
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/numpy/ufunc_api.py:183, in ufunc.__call__(self, out, where, *args)
#     181   raise NotImplementedError(f"where argument of {self}")
#     182 call = self.__static_props['call'] or self._call_vectorized
# --> 183 return call(*args)
#
#     [... skipping hidden 1 frame]
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/pjit.py:260, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     255 if config.no_tracing.value:
#     256   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     257                      "`jit`, but 'no_tracing' is set")
#     259 outs, out_flat, out_tree, args_flat, jaxpr, executable, pgle_profiler = \
# --> 260     _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     262 maybe_fastpath_data = _get_fastpath_data(
#     263     executable, out_tree, args_flat, out_flat, jaxpr.effects, jaxpr.consts,
#     264     jit_info.abstracted_axes, pgle_profiler)
#     266 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/pjit.py:149, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     147   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     148 else:
# --> 149   out_flat = jit_p.bind(*args_flat, **p.params)
#     150   compiled = None
#     151   profiler = None
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:576, in Primitive.bind(self, *args, **params)
#     574 def bind(self, *args, **params):
#     575   args = args if self.skip_canonicalization else map(canonicalize_value, args)
# --> 576   return self._true_bind(*args, **params)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:592, in Primitive._true_bind(self, *args, **params)
#     590 trace_ctx.set_trace(eval_trace)
#     591 try:
# --> 592   return self.bind_with_trace(prev_trace, args, params)
#     593 finally:
#     594   trace_ctx.set_trace(prev_trace)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/core.py:602, in Primitive.bind_with_trace(self, trace, args, params)
#     599   with set_current_trace(trace):
#     600     return self.to_lojax(*args, **params)  # type: ignore
# --> 602 return trace.process_primitive(self, args, params)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:742, in LinearizeTrace.process_primitive(self, primitive, args, params)
#     740   tangent_out = linearized(residuals, *tangents_in)
#     741 if primitive.multiple_results:
# --> 742   return [maybe_linearize_tracer(self, x, nz, t)
#     743           for x, nz, t in zip(primal_out, tangent_nzs_out, tangent_out)]
#     744 else:
#     745   return maybe_linearize_tracer(self, primal_out, tangent_nzs_out, tangent_out)
#
# File ~/Desktop/codes/codes_venvnew/lib/python3.13/site-packages/jax/_src/interpreters/ad.py:883, in maybe_linearize_tracer(trace, primal, is_nonzero, tangent)
#     878   # The only difference between process_map and process_call is that
#     879   # the `in_axes` and `out_axes_thunk` params must be updated;
#     880   # that's handled in process_call.
#     881   process_map = process_call
# --> 883 def maybe_linearize_tracer(trace, primal, is_nonzero, tangent):
#     884   if is_nonzero:
#     885     assert not type(tangent) is Zero
#
# KeyboardInterrupt:

# %%
loss_matrix = np.array(all_losses)
mu_err_matrix = np.array(all_mu_errors)/np.linalg.norm(mu)
cov_err_matrix = np.array(all_cov_errors)/np.linalg.norm(cov)


steps = np.linspace(0, n_steps, n_steps)
sample_sizes = np.arange(50, 2001, 50)


def plot_heatmap(data, title, ylabel, cmap="viridis", vmin=None, vmax=None):
    plt.imshow(data, aspect="auto", origin="lower", cmap=cmap,
               extent=[steps[0], steps[-1], sample_sizes[0], sample_sizes[-1]],
               vmin=vmin, vmax=vmax)
    plt.colorbar()
    plt.xlabel("step", fontsize=13)
    plt.ylabel("n_samples", fontsize=13)
    plt.title(title, fontsize=15)


plt.figure(figsize=(18, 5))


plt.subplot(1, 3, 1)
plot_heatmap(loss_matrix, "Loss heatmap", "n_samples")


plt.subplot(1, 3, 2)
plot_heatmap(mu_err_matrix, r"$\|\mu - \hat{\mu}\|_2/\|\mu\|_2$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.subplot(1, 3, 3)
plot_heatmap(cov_err_matrix, r"$\|\Sigma - \hat{\Sigma}\|_F/\|\Sigma\|_F$ heatmap", "n_samples", vmin=0.0, vmax=1.0)


plt.tight_layout()
plt.show()
